# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import numpy as np

# %% [markdown]
# # ****FOR FLIPKART WEBSITE****

# %% [markdown]
# **Data Extraction Process**

# %%
name =[]
prices = []
ratings = []
reviews = []
links = []
start_link = "https://www.flipkart.com"
df = pd.DataFrame()

# %%
page = 1
titles = []
while page != 100 :
      url = f"https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page={page}"
      response = requests.get(url)
      html = response.content   #retrieves the raw HTML content of the response, including any HTML tags, attributes, and text within the response.
      soup = BeautifulSoup(response.text,"html.parser")  # Initializes a BeautifulSoup object named soup using the HTML content as a string and specifies the parser to be used as "html.parser". 
                                                          #This allows you to parse and navigate the HTML structure of the webpage easily using BeautifulSoup methods and functions.
      data = soup.find_all("div",{"class":"_2kHMtA"})
      for h3 in soup.find_all("div",{"class":"_2kHMtA"}):

        titles.append(h3)
      page = page + 1

# %%
len(titles)  #number of laptops that were extracted
# Out:
# 912

# %%
box = titles[0]  #to check for the format in the flipkart website
box
# Out:
# <div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/primebook-4g-android-based-mediatek-mt8788-4-gb-64-gb-emmc-storage-prime-os-thin-light-laptop/p/itmecb7e931de990?pid=COMGH2NKYVZCVXAW&amp;lid=LSTCOMGH2NKYVZCVXAWAYX3II&amp;marketplace=FLIPKART&amp;q=laptops&amp;store=6bo%2Fb5g&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_MZrqH6eKWjRUxWwWaIvX%2BmQjkLv%2B2sBdWWje19OJMyEOAHVp5s0G1I0Un041P26HTHX68G9wSi4vlIVeHtxGzw%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=nz4a7ycvps0000001684914505681&amp;qH=c06ea84a1e3dc3c6" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt..." class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTCOMGH2NKYVZCVXAWAYX3II_COMGH2NKYVZCVXAW_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>563 Ratings </span><span class="_13vcmD">&amp;</span><span> 195 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">MediaTek MediaTek MT8788 Processor</li><li class="rgWa7D">4 GB LPDDR4 RAM</li><li class="rgWa7D">Prime OS Operating System</li><li class="rgWa7D">29.46 cm (11.6 Inch) Display</li><li class="rgWa7D">1 Year walk-in warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹16,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->24,990</div><div class="_3Ay6Sb"><span>32% off</span></div></div><div class="_3tcB5a p8ucoS"><div><div class="_2Tpdn3" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div></div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">Upto </div><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:700">₹16,300</div><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400"> Off on Exchange</div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#26A541;font-size:14px;font-weight:700">Bank Offer</div></div></div></div></div></a></div>

# %%
data_list = [] 
for box in titles:   #iterating through all the laptops

  temp_dict = {}
  temp_dict["Title"] = box.find('div',{'class':'_4rR01T'}).text.strip()   #getting specifications of the product

  temp_dict["Price(₹)"] = box.find('div',{'class':'_30jeq3 _1_WHN1'}).text.replace("₹","").strip() if box.find('div',{'class':'_30jeq3 _1_WHN1'}) else None   #price of the product
  temp_dict["Rating"] = box.find('div',{'class':"_3LWZlK"}).text.strip() if box.find("div", {"class": "_3LWZlK"}) else None     #rating of the product
  temp_dict["Reviews"] = reviews = box.find('span', attrs={'class' : '_2_R_DZ'}).text if box.find('span', attrs={'class' : '_2_R_DZ'}) else None   #reviews of the product
  rest_link = box.find('a')['href']
  #name_items =box.find('div',{'class': '_1fQZEK'})
  links = (start_link + rest_link)
  temp_dict["Product Links"] = links
  data_list.append(temp_dict)

# %%
laptops_df = pd.DataFrame(data_list)
laptops_df
# Out:
#                                                  Title Price(₹) Rating  \
# 0    Primebook 4G Android Based MediaTek MT8788 - (...   16,990      4
# 1    Primebook 4G Android Based MediaTek MT8788 - (...   18,990    4.1
# 2    HP Celeron Dual Core - (8 GB/256 GB SSD/Window...   29,490    3.8
# 3    Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U - ...   32,990    4.2
# 4    RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...   37,990    4.1
# ..                                                 ...      ...    ...
# 907  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...   44,027    4.3
# 908  acer Swift 7 Core i5 7th Gen - (8 GB/256 GB SS...   80,990    4.4
# 909  Lenovo Ideapad 720S Core i5 8th Gen - (8 GB/51...   74,990    3.3
# 910  MSI Core i3 12th Gen - (8 GB/512 GB SSD/Window...   42,990    4.5
# 911  Lenovo IdeaPad 3 Intel Core i3 11th Gen - (8 G...   38,990    4.3
#
#                          Reviews  \
# 0      563 Ratings & 195 Reviews
# 1        98 Ratings & 37 Reviews
# 2       323 Ratings & 32 Reviews
# 3       120 Ratings & 27 Reviews
# 4    5,507 Ratings & 622 Reviews
# ..                           ...
# 907  1,836 Ratings & 196 Reviews
# 908       39 Ratings & 3 Reviews
# 909        3 Ratings & 1 Reviews
# 910       11 Ratings & 3 Reviews
# 911  5,175 Ratings & 479 Reviews
#
#                                          Product Links
# 0    https://www.flipkart.com/primebook-4g-android-...
# 1    https://www.flipkart.com/primebook-4g-android-...
# 2    https://www.flipkart.com/hp-celeron-dual-core-...
# 3    https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4    https://www.flipkart.com/redmibook-pro-core-i5...
# ..                                                 ...
# 907  https://www.flipkart.com/lenovo-ideapad-3-ryze...
# 908  https://www.flipkart.com/acer-swift-7-core-i5-...
# 909  https://www.flipkart.com/lenovo-ideapad-720s-c...
# 910  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 911  https://www.flipkart.com/lenovo-ideapad-3-inte...
#
# [912 rows x 5 columns]

# %% [markdown]
# **Data Transformation:**

# %%
laptops_df['Price(₹)'] = laptops_df['Price(₹)'].str.replace(',', '')

# %%
laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
del laptops_df['Title']
laptops_df.head()
# Out:
# <ipython-input-48-ecca7ce829d3>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
# <ipython-input-48-ecca7ce829d3>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
#   Price(₹) Rating                      Reviews  \
# 0    16990      4    563 Ratings & 195 Reviews
# 1    18990    4.1      98 Ratings & 37 Reviews
# 2    29490    3.8     323 Ratings & 32 Reviews
# 3    32990    4.2     120 Ratings & 27 Reviews
# 4    37990    4.1  5,507 Ratings & 622 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/primebook-4g-android-...
# 1  https://www.flipkart.com/primebook-4g-android-...
# 2  https://www.flipkart.com/hp-celeron-dual-core-...
# 3  https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4  https://www.flipkart.com/redmibook-pro-core-i5...
#
#                                           model  \
# 0   Primebook 4G Android Based MediaTek MT8788
# 1   Primebook 4G Android Based MediaTek MT8788
# 2                         HP Celeron Dual Core
# 3  Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U
# 4               RedmiBook Pro Core i5 11th Gen
#
#                                       Specifications
# 0   (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin an...
# 1   (4 GB/128 GB EMMC Storage/Prime OS) 4G Thin a...
# 2   (8 GB/256 GB SSD/Windows 11 Home) 14s-dq3037t...
# 3   (8 GB/512 GB SSD/Windows 11 Home) TB15 G3 ACL...
# 4   (8 GB/512 GB SSD/Windows 11 Home) Thin and Li...

# %%
laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
del laptops_df['Specifications']
laptops_df.head()
# Out:
# <ipython-input-49-ee3b3de57827>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
# <ipython-input-49-ee3b3de57827>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
#   Price(₹) Rating                      Reviews  \
# 0    16990      4    563 Ratings & 195 Reviews
# 1    18990    4.1      98 Ratings & 37 Reviews
# 2    29490    3.8     323 Ratings & 32 Reviews
# 3    32990    4.2     120 Ratings & 27 Reviews
# 4    37990    4.1  5,507 Ratings & 622 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/primebook-4g-android-...
# 1  https://www.flipkart.com/primebook-4g-android-...
# 2  https://www.flipkart.com/hp-celeron-dual-core-...
# 3  https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4  https://www.flipkart.com/redmibook-pro-core-i5...
#
#                                           model RAM(GB)  \
# 0   Primebook 4G Android Based MediaTek MT8788
# 1   Primebook 4G Android Based MediaTek MT8788
# 2                         HP Celeron Dual Core
# 3  Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U
# 4               RedmiBook Pro Core i5 11th Gen
#
#                                      Hard Disk Drive
# 0  4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and ...
# 1  4 GB/128 GB EMMC Storage/Prime OS) 4G Thin and...
# 2  8 GB/256 GB SSD/Windows 11 Home) 14s-dq3037tu ...
# 3  8 GB/512 GB SSD/Windows 11 Home) TB15 G3 ACL T...
# 4  8 GB/512 GB SSD/Windows 11 Home) Thin and Ligh...

# %%
laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
del laptops_df['Hard Disk Drive']
laptops_df.head()
# Out:
# <ipython-input-50-937877900a55>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
# <ipython-input-50-937877900a55>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
#   Price(₹) Rating                      Reviews  \
# 0    16990      4    563 Ratings & 195 Reviews
# 1    18990    4.1      98 Ratings & 37 Reviews
# 2    29490    3.8     323 Ratings & 32 Reviews
# 3    32990    4.2     120 Ratings & 27 Reviews
# 4    37990    4.1  5,507 Ratings & 622 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/primebook-4g-android-...
# 1  https://www.flipkart.com/primebook-4g-android-...
# 2  https://www.flipkart.com/hp-celeron-dual-core-...
# 3  https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4  https://www.flipkart.com/redmibook-pro-core-i5...
#
#                                           model RAM(GB)  \
# 0   Primebook 4G Android Based MediaTek MT8788     4 GB
# 1   Primebook 4G Android Based MediaTek MT8788     4 GB
# 2                         HP Celeron Dual Core     8 GB
# 3  Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U     8 GB
# 4               RedmiBook Pro Core i5 11th Gen     8 GB
#
#                                            Hard Disk
# 0  64 GB EMMC Storage/Prime OS) 4G Thin and Light...
# 1  128 GB EMMC Storage/Prime OS) 4G Thin and Ligh...
# 2  256 GB SSD/Windows 11 Home) 14s-dq3037tu Thin ...
# 3  512 GB SSD/Windows 11 Home) TB15 G3 ACL Thin a...
# 4  512 GB SSD/Windows 11 Home) Thin and Light Laptop

# %%
laptops_df['RAM(GB)'] = laptops_df['RAM(GB)'].str.replace('GB', '')

# %%
laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
del laptops_df['Hard Disk']
laptops_df.head()
# Out:
# <ipython-input-52-d5977b3ecc1c>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
# <ipython-input-52-d5977b3ecc1c>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
#   Price(₹) Rating                      Reviews  \
# 0    16990      4    563 Ratings & 195 Reviews
# 1    18990    4.1      98 Ratings & 37 Reviews
# 2    29490    3.8     323 Ratings & 32 Reviews
# 3    32990    4.2     120 Ratings & 27 Reviews
# 4    37990    4.1  5,507 Ratings & 622 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/primebook-4g-android-...
# 1  https://www.flipkart.com/primebook-4g-android-...
# 2  https://www.flipkart.com/hp-celeron-dual-core-...
# 3  https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4  https://www.flipkart.com/redmibook-pro-core-i5...
#
#                                           model RAM(GB)                  HDD  \
# 0   Primebook 4G Android Based MediaTek MT8788       4    64 GB EMMC Storage
# 1   Primebook 4G Android Based MediaTek MT8788       4   128 GB EMMC Storage
# 2                         HP Celeron Dual Core       8            256 GB SSD
# 3  Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U       8            512 GB SSD
# 4               RedmiBook Pro Core i5 11th Gen       8            512 GB SSD
#
#                                       specifications
# 0                Prime OS) 4G Thin and Light Lapt...
# 1                 Prime OS) 4G Thin and Light Lap...
# 2  Windows 11 Home) 14s-dq3037tu Thin and Light L...
# 3         Windows 11 Home) TB15 G3 ACL Thin and L...
# 4             Windows 11 Home) Thin and Light Laptop

# %%
laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
del laptops_df['model'] 
laptops_df.head()
# Out:
# <ipython-input-53-cef07114d64a>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
# <ipython-input-53-cef07114d64a>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
#   Price(₹) Rating                      Reviews  \
# 0    16990      4    563 Ratings & 195 Reviews
# 1    18990    4.1      98 Ratings & 37 Reviews
# 2    29490    3.8     323 Ratings & 32 Reviews
# 3    32990    4.2     120 Ratings & 27 Reviews
# 4    37990    4.1  5,507 Ratings & 622 Reviews
#
#                                        Product Links RAM(GB)  \
# 0  https://www.flipkart.com/primebook-4g-android-...      4
# 1  https://www.flipkart.com/primebook-4g-android-...      4
# 2  https://www.flipkart.com/hp-celeron-dual-core-...      8
# 3  https://www.flipkart.com/lenovo-thinkbook-15-r...      8
# 4  https://www.flipkart.com/redmibook-pro-core-i5...      8
#
#                    HDD                                     specifications  \
# 0   64 GB EMMC Storage                Prime OS) 4G Thin and Light Lapt...
# 1  128 GB EMMC Storage                 Prime OS) 4G Thin and Light Lap...
# 2           256 GB SSD  Windows 11 Home) 14s-dq3037tu Thin and Light L...
# 3           512 GB SSD         Windows 11 Home) TB15 G3 ACL Thin and L...
# 4           512 GB SSD             Windows 11 Home) Thin and Light Laptop
#
#      Company                                  Model
# 0  Primebook      4G Android Based MediaTek MT8788
# 1  Primebook      4G Android Based MediaTek MT8788
# 2         HP                     Celeron Dual Core
# 3     Lenovo  ThinkBook 15 Ryzen 3 Hexa Core 5300U
# 4  RedmiBook                  Pro Core i5 11th Gen

# %%
laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
del laptops_df['Reviews']  
del laptops_df['Ratings']
laptops_df.head()
# Out:
# <ipython-input-54-03ef260febaf>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
# <ipython-input-54-03ef260febaf>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    16990      4  https://www.flipkart.com/primebook-4g-android-...      4
# 1    18990    4.1  https://www.flipkart.com/primebook-4g-android-...      4
# 2    29490    3.8  https://www.flipkart.com/hp-celeron-dual-core-...      8
# 3    32990    4.2  https://www.flipkart.com/lenovo-thinkbook-15-r...      8
# 4    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
#
#                    HDD                                     specifications  \
# 0   64 GB EMMC Storage                Prime OS) 4G Thin and Light Lapt...
# 1  128 GB EMMC Storage                 Prime OS) 4G Thin and Light Lap...
# 2           256 GB SSD  Windows 11 Home) 14s-dq3037tu Thin and Light L...
# 3           512 GB SSD         Windows 11 Home) TB15 G3 ACL Thin and L...
# 4           512 GB SSD             Windows 11 Home) Thin and Light Laptop
#
#      Company                                  Model Total Reviews
# 0  Primebook      4G Android Based MediaTek MT8788            563
# 1  Primebook      4G Android Based MediaTek MT8788             98
# 2         HP                     Celeron Dual Core            323
# 3     Lenovo  ThinkBook 15 Ryzen 3 Hexa Core 5300U            120
# 4  RedmiBook                  Pro Core i5 11th Gen          5,507

# %%
regex = r"(\d+\s?(?:GB|TB))\s?(\b(?:SSD|HDD)\b)"
laptops_df[['Hard Disk', 'Storage_Type']] = laptops_df['HDD'].str.extract(regex)
del laptops_df['HDD']  
del laptops_df['Storage_Type']
laptops_df.head()
# Out:
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    16990      4  https://www.flipkart.com/primebook-4g-android-...      4
# 1    18990    4.1  https://www.flipkart.com/primebook-4g-android-...      4
# 2    29490    3.8  https://www.flipkart.com/hp-celeron-dual-core-...      8
# 3    32990    4.2  https://www.flipkart.com/lenovo-thinkbook-15-r...      8
# 4    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
#
#                                       specifications    Company  \
# 0                Prime OS) 4G Thin and Light Lapt...  Primebook
# 1                 Prime OS) 4G Thin and Light Lap...  Primebook
# 2  Windows 11 Home) 14s-dq3037tu Thin and Light L...         HP
# 3         Windows 11 Home) TB15 G3 ACL Thin and L...     Lenovo
# 4             Windows 11 Home) Thin and Light Laptop  RedmiBook
#
#                                    Model Total Reviews Hard Disk
# 0      4G Android Based MediaTek MT8788            563       NaN
# 1      4G Android Based MediaTek MT8788             98       NaN
# 2                     Celeron Dual Core            323    256 GB
# 3  ThinkBook 15 Ryzen 3 Hexa Core 5300U            120    512 GB
# 4                  Pro Core i5 11th Gen          5,507    512 GB

# %%
regex = r"((?:Windows \d+|Mac OS \w+))\b(.*)"
laptops_df[['Operating_System', 'Other_Details']] = laptops_df['specifications'].str.extract(regex)
del laptops_df['specifications']
del laptops_df['Other_Details']
laptops_df
# Out:
#     Price(₹) Rating                                      Product Links  \
# 0      16990      4  https://www.flipkart.com/primebook-4g-android-...
# 1      18990    4.1  https://www.flipkart.com/primebook-4g-android-...
# 2      29490    3.8  https://www.flipkart.com/hp-celeron-dual-core-...
# 3      32990    4.2  https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4      37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...
# ..       ...    ...                                                ...
# 907    44027    4.3  https://www.flipkart.com/lenovo-ideapad-3-ryze...
# 908    80990    4.4  https://www.flipkart.com/acer-swift-7-core-i5-...
# 909    74990    3.3  https://www.flipkart.com/lenovo-ideapad-720s-c...
# 910    42990    4.5  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 911    38990    4.3  https://www.flipkart.com/lenovo-ideapad-3-inte...
#
#     RAM(GB)    Company                                  Model Total Reviews  \
# 0        4   Primebook      4G Android Based MediaTek MT8788            563
# 1        4   Primebook      4G Android Based MediaTek MT8788             98
# 2        8          HP                     Celeron Dual Core            323
# 3        8      Lenovo  ThinkBook 15 Ryzen 3 Hexa Core 5300U            120
# 4        8   RedmiBook                  Pro Core i5 11th Gen          5,507
# ..      ...        ...                                    ...           ...
# 907      8      Lenovo     IdeaPad 3 Ryzen 5 Hexa Core 5500U          1,836
# 908      8        acer               Swift 7 Core i5 7th Gen             39
# 909      8      Lenovo          Ideapad 720S Core i5 8th Gen              3
# 910      8         MSI                      Core i3 12th Gen             11
# 911      8      Lenovo      IdeaPad 3 Intel Core i3 11th Gen          5,175
#
#     Hard Disk Operating_System
# 0         NaN              NaN
# 1         NaN              NaN
# 2      256 GB       Windows 11
# 3      512 GB       Windows 11
# 4      512 GB       Windows 11
# ..        ...              ...
# 907    512 GB       Windows 11
# 908    256 GB       Windows 10
# 909    512 GB       Windows 10
# 910    512 GB       Windows 11
# 911    512 GB       Windows 11
#
# [912 rows x 9 columns]

# %%
laptops_df.head()
# Out:
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    16990      4  https://www.flipkart.com/primebook-4g-android-...      4
# 1    18990    4.1  https://www.flipkart.com/primebook-4g-android-...      4
# 2    29490    3.8  https://www.flipkart.com/hp-celeron-dual-core-...      8
# 3    32990    4.2  https://www.flipkart.com/lenovo-thinkbook-15-r...      8
# 4    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
#
#      Company                                  Model Total Reviews Hard Disk  \
# 0  Primebook      4G Android Based MediaTek MT8788            563       NaN
# 1  Primebook      4G Android Based MediaTek MT8788             98       NaN
# 2         HP                     Celeron Dual Core            323    256 GB
# 3     Lenovo  ThinkBook 15 Ryzen 3 Hexa Core 5300U            120    512 GB
# 4  RedmiBook                  Pro Core i5 11th Gen          5,507    512 GB
#
#   Operating_System
# 0              NaN
# 1              NaN
# 2       Windows 11
# 3       Windows 11
# 4       Windows 11

# %%
laptops_df = laptops_df[['Company','Operating_System','Model','RAM(GB)', 'Hard Disk' ,'Price(₹)', 'Rating','Total Reviews','Product Links']]  #we have to del specifications if not needed
laptops_df
# Out:
#        Company Operating_System                                  Model  \
# 0    Primebook              NaN      4G Android Based MediaTek MT8788
# 1    Primebook              NaN      4G Android Based MediaTek MT8788
# 2           HP       Windows 11                     Celeron Dual Core
# 3       Lenovo       Windows 11  ThinkBook 15 Ryzen 3 Hexa Core 5300U
# 4    RedmiBook       Windows 11                  Pro Core i5 11th Gen
# ..         ...              ...                                    ...
# 907     Lenovo       Windows 11     IdeaPad 3 Ryzen 5 Hexa Core 5500U
# 908       acer       Windows 10               Swift 7 Core i5 7th Gen
# 909     Lenovo       Windows 10          Ideapad 720S Core i5 8th Gen
# 910        MSI       Windows 11                      Core i3 12th Gen
# 911     Lenovo       Windows 11      IdeaPad 3 Intel Core i3 11th Gen
#
#     RAM(GB) Hard Disk Price(₹) Rating Total Reviews  \
# 0        4        NaN    16990      4           563
# 1        4        NaN    18990    4.1            98
# 2        8     256 GB    29490    3.8           323
# 3        8     512 GB    32990    4.2           120
# 4        8     512 GB    37990    4.1         5,507
# ..      ...       ...      ...    ...           ...
# 907      8     512 GB    44027    4.3         1,836
# 908      8     256 GB    80990    4.4            39
# 909      8     512 GB    74990    3.3             3
# 910      8     512 GB    42990    4.5            11
# 911      8     512 GB    38990    4.3         5,175
#
#                                          Product Links
# 0    https://www.flipkart.com/primebook-4g-android-...
# 1    https://www.flipkart.com/primebook-4g-android-...
# 2    https://www.flipkart.com/hp-celeron-dual-core-...
# 3    https://www.flipkart.com/lenovo-thinkbook-15-r...
# 4    https://www.flipkart.com/redmibook-pro-core-i5...
# ..                                                 ...
# 907  https://www.flipkart.com/lenovo-ideapad-3-ryze...
# 908  https://www.flipkart.com/acer-swift-7-core-i5-...
# 909  https://www.flipkart.com/lenovo-ideapad-720s-c...
# 910  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 911  https://www.flipkart.com/lenovo-ideapad-3-inte...
#
# [912 rows x 9 columns]

# %%
laptops_df.to_csv("Laptops_df.csv",index = False,encoding = 'utf-8')

# %% [markdown]
# #****FOR AMAZON WEBSITE****

# %% [markdown]
# **Data Extraction**

# %%
# Function to extract Product Title
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id":'productTitle'})    # Outer Tag Object
        title_value = title.text                                  # Inner NavigatableString Object
        title_string = title_value.strip()                        # Title as a string value
    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find("span", attrs={'class':'a-price aok-align-center reinventPricePriceToPayMargin priceToPay'}).find('span', attrs= {'class' : "a-price-whole"}).text
    except AttributeError:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip() 
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:70.0) Gecko/20100101 Firefox/70.0'})  #User-Agent header is used to mimic a web browser when making HTTP requests
page = 1
links_list = []       # Store the links
    
while page != 3:
    URL = f"https://www.amazon.in/s?k=laptops&page={page}&qid=1681297837&ref=sr_pg_{page}"
    product_links = []
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})



    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
    d = {"Title":[], "Price(₹)":[], "Rating":[], "Reviews":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)
        product_links.append("https://www.amazon.in" + link)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['Title'].append(get_title(new_soup))
        d['Price(₹)'].append(get_price(new_soup))
        d['Rating'].append(get_rating(new_soup)) 
        d['Reviews'].append(get_review_count(new_soup))
    d['Product Links'] = product_links
    page = page + 1
   
    amazon = pd.DataFrame.from_dict(d)
    
    amazon['Title'].replace('', np.nan, inplace=True)
    amazon = amazon.dropna(subset=['Title'])

# %%
amazon_site = links[1]
amazon_site
# Out:
# <a class="a-link-normal s-no-outline" href="/Lenovo-IdeaPad-39-62cm-Warranty-82H802XXIN/dp/B0BN4JZVRR/ref=sr_1_18?keywords=laptops&amp;qid=1684935934&amp;sr=8-18" target="_blank"><div class="a-section aok-relative s-image-fixed-height"><img alt='Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen 15.6" (39.62cm) FHD Laptop (16GB/512GB SSD/Win 11/Office 2021/2 Years Warrant...' class="s-image" data-image-index="18" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY654_QL65_.jpg 3x"/></div></a>

# %%
amazon.head(10)
# Out:
#                                       Specifications Price(?)  \
# 0  Dell Inspiron 5518 Laptop, Intel Core i5-11320...   67,600
# 1  MSI Modern 14, Intel 13th Gen. i3-1315U, 36CM ...   49,990
# 2  Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...   20,990
# 3  (Renewed) Lenovo T440p ThinkPad 4th Gen Intel ...     None
# 4  Dell New Inspiron 3515 Windows Laptop, AMD Ryz...   41,500
# 5  (Renewed) Lenovo IdeaPad Slim 3 Intel Core i3 ...     None
# 6  ASUS VivoBook 15, Intel Celeron N4020, 15.6" (...   26,780
# 7  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...   38,500
# 8  (Renewed) HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB...     None
# 9  Lenovo V15 Intel Celeron N4020 15.6 inches HD ...   22,999
#
#               Ratings      Reviews  \
# 0  3.9 out of 5 stars   27 ratings
# 1                None         None
# 2  3.4 out of 5 stars    5 ratings
# 3  3.6 out of 5 stars   86 ratings
# 4  3.4 out of 5 stars    6 ratings
# 5                None         None
# 6  3.0 out of 5 stars   37 ratings
# 7  4.0 out of 5 stars  333 ratings
# 8  2.7 out of 5 stars    3 ratings
# 9  3.5 out of 5 stars    3 ratings
#
#                                        Product Links
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...
# 5  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...
# 6  https://www.amazon.in/ASUS-VivoBook-Integrated...
# 7  https://www.amazon.in/Dell-Inspiron-Graphics-A...
# 8  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...
# 9  https://www.amazon.in/Lenovo-Celeron-Windows-M...

# %% [markdown]
# **Data Transformation**

# %%
amazon = amazon.rename(columns={'Price(?)': 'Price(₹)'})
amazon = amazon.rename(columns={'Rating': 'Ratings'})
amazon.head(10)
# Out:
#                                       Specifications Price(₹)  \
# 0  Dell Inspiron 5518 Laptop, Intel Core i5-11320...   67,600
# 1  MSI Modern 14, Intel 13th Gen. i3-1315U, 36CM ...   49,990
# 2  Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...   20,990
# 3  (Renewed) Lenovo T440p ThinkPad 4th Gen Intel ...     None
# 4  Dell New Inspiron 3515 Windows Laptop, AMD Ryz...   41,500
# 5  (Renewed) Lenovo IdeaPad Slim 3 Intel Core i3 ...     None
# 6  ASUS VivoBook 15, Intel Celeron N4020, 15.6" (...   26,780
# 7  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...   38,500
# 8  (Renewed) HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB...     None
# 9  Lenovo V15 Intel Celeron N4020 15.6 inches HD ...   22,999
#
#               Ratings      Reviews  \
# 0  3.9 out of 5 stars   27 ratings
# 1                None         None
# 2  3.4 out of 5 stars    5 ratings
# 3  3.6 out of 5 stars   86 ratings
# 4  3.4 out of 5 stars    6 ratings
# 5                None         None
# 6  3.0 out of 5 stars   37 ratings
# 7  4.0 out of 5 stars  333 ratings
# 8  2.7 out of 5 stars    3 ratings
# 9  3.5 out of 5 stars    3 ratings
#
#                                        Product Links
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...
# 5  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...
# 6  https://www.amazon.in/ASUS-VivoBook-Integrated...
# 7  https://www.amazon.in/Dell-Inspiron-Graphics-A...
# 8  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...
# 9  https://www.amazon.in/Lenovo-Celeron-Windows-M...

# %%
amazon['Price(₹)'] = amazon['Price(₹)'].str.replace(',', '')

# %%
amazon.head()
# Out:
#   Price(₹)             Ratings     Reviews  \
# 0    67600  3.9 out of 5 stars  27 ratings
# 1    49990                None        None
# 2    20990  3.4 out of 5 stars   5 ratings
# 3     None  3.6 out of 5 stars  86 ratings
# 4    41500  3.4 out of 5 stars   6 ratings
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell              NaN
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI       Windows 11
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo       Windows 10
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo       Windows 10
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell              NaN
#
#                                                Model RAM(GB)
# 0  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8
# 1  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8
# 2  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4
# 3  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8
# 4  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8

# %%
import pandas as pd

amazon['Company'] = amazon['Specifications'].str.extract(r"(?:\(Renewed\)\s)?([A-Za-z]+)")

amazon.head(10)
# Out:
#                                       Specifications Price(₹)  \
# 0  Dell Inspiron 5518 Laptop, Intel Core i5-11320...   67,600
# 1  MSI Modern 14, Intel 13th Gen. i3-1315U, 36CM ...   49,990
# 2  Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...   20,990
# 3  (Renewed) Lenovo T440p ThinkPad 4th Gen Intel ...     None
# 4  Dell New Inspiron 3515 Windows Laptop, AMD Ryz...   41,500
# 5  (Renewed) Lenovo IdeaPad Slim 3 Intel Core i3 ...     None
# 6  ASUS VivoBook 15, Intel Celeron N4020, 15.6" (...   26,780
# 7  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...   38,500
# 8  (Renewed) HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB...     None
# 9  Lenovo V15 Intel Celeron N4020 15.6 inches HD ...   22,999
#
#               Ratings      Reviews  \
# 0  3.9 out of 5 stars   27 ratings
# 1                None         None
# 2  3.4 out of 5 stars    5 ratings
# 3  3.6 out of 5 stars   86 ratings
# 4  3.4 out of 5 stars    6 ratings
# 5                None         None
# 6  3.0 out of 5 stars   37 ratings
# 7  4.0 out of 5 stars  333 ratings
# 8  2.7 out of 5 stars    3 ratings
# 9  3.5 out of 5 stars    3 ratings
#
#                                        Product Links Company
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# 5  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...  Lenovo
# 6  https://www.amazon.in/ASUS-VivoBook-Integrated...    ASUS
# 7  https://www.amazon.in/Dell-Inspiron-Graphics-A...    Dell
# 8  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...      HP
# 9  https://www.amazon.in/Lenovo-Celeron-Windows-M...  Lenovo

# %%
regex = r"(?i)\b((?:Windows\s+\d+|Mac(?:Book)?|Linux|Unix|Ubuntu|DOS)\b)"
amazon['Operating_System'] = amazon['Specifications'].str.extract(regex, flags=re.IGNORECASE)
amazon['Operating_System'] = amazon['Operating_System'].str.replace('MacBook', 'Mac', regex=True)

# %%
amazon.head(124)
# Out:
#                                         Specifications Price(₹)  \
# 0    Dell Inspiron 5518 Laptop, Intel Core i5-11320...   67,600
# 1    MSI Modern 14, Intel 13th Gen. i3-1315U, 36CM ...   49,990
# 2    Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...   20,990
# 3    (Renewed) Lenovo T440p ThinkPad 4th Gen Intel ...     None
# 4    Dell New Inspiron 3515 Windows Laptop, AMD Ryz...   41,500
# ..                                                 ...      ...
# 119  Lenovo V15 AMD Ryzen 3 5300U 15.6" (39.62cm) F...   32,990
# 120  Dell New 14" Latitude 3420- i3 11th Gen || 8 G...   31,990
# 121  HP Pavilion Plus, 12th Gen Intel Core i5 16GB ...   76,990
# 122  Lenovo V15-ADA (82C700KDIH) Laptop (AMD Ryzen ...   39,999
# 123  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 5600H 15.6...   53,990
#
#                 Ratings      Reviews  \
# 0    3.9 out of 5 stars   27 ratings
# 1                  None         None
# 2    3.4 out of 5 stars    5 ratings
# 3    3.6 out of 5 stars   86 ratings
# 4    3.4 out of 5 stars    6 ratings
# ..                  ...          ...
# 119  2.5 out of 5 stars    2 ratings
# 120                None         None
# 121  3.9 out of 5 stars   38 ratings
# 122  4.0 out of 5 stars    2 ratings
# 123  4.2 out of 5 stars  358 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1    https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2    https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3    https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4    https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# ..                                                 ...     ...
# 119  https://www.amazon.in/Lenovo-39-62cm-Antiglare...  Lenovo
# 120  https://www.amazon.in/Dell-Latitude-Pixels-Ubu...    Dell
# 121  https://www.amazon.in/HP-Pavilion-Display-Grap...      HP
# 122  https://www.amazon.in/Lenovo-V15-ADA-82C700KDI...  Lenovo
# 123  https://www.amazon.in/Lenovo-IdeaPad-39-62cm-W...  Lenovo
#
#     Operating_System
# 0                NaN
# 1         Windows 11
# 2         Windows 10
# 3         Windows 10
# 4                NaN
# ..               ...
# 119              DOS
# 120           Ubuntu
# 121              NaN
# 122       Windows 10
# 123       Windows 11
#
# [124 rows x 7 columns]

# %%
amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
del amazon['company']
del amazon['Specifications'] 
amazon.head()
# Out:
# <ipython-input-18-8a969cfc8a3e>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
# <ipython-input-18-8a969cfc8a3e>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
#   Price(₹)             Ratings     Reviews  \
# 0   67,600  3.9 out of 5 stars  27 ratings
# 1   49,990                None        None
# 2   20,990  3.4 out of 5 stars   5 ratings
# 3     None  3.6 out of 5 stars  86 ratings
# 4   41,500  3.4 out of 5 stars   6 ratings
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell              NaN
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI       Windows 11
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo       Windows 10
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo       Windows 10
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell              NaN
#
#                                                Model
# 0  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...
# 1  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...
# 2  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...
# 3  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...
# 4  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...

# %%
import pandas as pd
import re


pattern = r"(\d+)\s?[Gg][Bb]"

# Define a function to extract RAM information from a string
def extract_ram(description):
    match = re.search(pattern, description)
    if match:
        return match.group(0)
    else:
        return None

# Apply the function to the 'Product_Description' column and create a new column 'RAM'
amazon['Model'] = amazon['Model'].astype(str)
amazon['RAM(GB)'] = amazon['Model'].apply(extract_ram)

# Print dataframe
amazon
# Out:
#     Price(₹)             Ratings      Reviews  \
# 0     67,600  3.9 out of 5 stars   27 ratings
# 1     49,990                None         None
# 2     20,990  3.4 out of 5 stars    5 ratings
# 3       None  3.6 out of 5 stars   86 ratings
# 4     41,500  3.4 out of 5 stars    6 ratings
# ..       ...                 ...          ...
# 378   19,990  3.8 out of 5 stars  276 ratings
# 379   41,990  4.1 out of 5 stars  140 ratings
# 380   72,990  4.0 out of 5 stars  168 ratings
# 381   41,990  4.1 out of 5 stars  140 ratings
# 382   40,990  3.6 out of 5 stars   50 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1    https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2    https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3    https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4    https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# ..                                                 ...     ...
# 378  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 379  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
# 380  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    ASUS
# 381  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
# 382  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
#
#     Operating_System                                              Model  \
# 0                NaN  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...
# 1         Windows 11  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...
# 2         Windows 10  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...
# 3         Windows 10  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...
# 4                NaN  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...
# ..               ...                                                ...
# 378              NaN  Chromebook 11a, MediaTek MT8183 Processor 11.6...
# 379              NaN  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...
# 380       Windows 11  Vivobook S15 OLED 2022, 15.6" 39.62 cm FHD OLE...
# 381              NaN  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...
# 382       Windows 11  Inspiron 3511 Laptop, Intel i3-1115G4, 8GB DDR...
#
#     RAM(GB)
# 0       8GB
# 1       8GB
# 2       4GB
# 3      8 GB
# 4       8GB
# ..      ...
# 378    4 GB
# 379     8GB
# 380    16GB
# 381     8GB
# 382     8GB
#
# [383 rows x 8 columns]

# %%
amazon['RAM(GB)'] = amazon['RAM(GB)'].str.replace('GB', '')

# %%
amazon['hard disk'] = amazon['Model'].str.extract(r"(\d+\s?(?:[Gg][Bb]|[Tt][Bb])?\s?(?:HDD|SSD|SDD))")

amazon
# Out:
#     Price(₹)             Ratings      Reviews  \
# 0      67600  3.9 out of 5 stars   27 ratings
# 1      49990                None         None
# 2      20990  3.4 out of 5 stars    5 ratings
# 3       None  3.6 out of 5 stars   86 ratings
# 4      41500  3.4 out of 5 stars    6 ratings
# ..       ...                 ...          ...
# 378    19990  3.8 out of 5 stars  276 ratings
# 379    41990  4.1 out of 5 stars  140 ratings
# 380    72990  4.0 out of 5 stars  168 ratings
# 381    41990  4.1 out of 5 stars  140 ratings
# 382    40990  3.6 out of 5 stars   50 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1    https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2    https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3    https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4    https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# ..                                                 ...     ...
# 378  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 379  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
# 380  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    ASUS
# 381  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
# 382  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...    Dell
#
#     Operating_System                                              Model  \
# 0                NaN  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...
# 1         Windows 11  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...
# 2         Windows 10  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...
# 3         Windows 10  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...
# 4                NaN  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...
# ..               ...                                                ...
# 378              NaN  Chromebook 11a, MediaTek MT8183 Processor 11.6...
# 379              NaN  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...
# 380       Windows 11  Vivobook S15 OLED 2022, 15.6" 39.62 cm FHD OLE...
# 381              NaN  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...
# 382       Windows 11  Inspiron 3511 Laptop, Intel i3-1115G4, 8GB DDR...
#
#     RAM(GB)   hard disk
# 0         8   512GB SSD
# 1         8         NaN
# 2         4   256GB SSD
# 3        8   500 GB HDD
# 4         8     1TB HDD
# ..      ...         ...
# 378      4          NaN
# 379       8   512GB SSD
# 380      16   512GB SSD
# 381       8   512GB SSD
# 382       8   512GB SSD
#
# [383 rows x 9 columns]

# %%
amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
del amazon['ssd'] 
del amazon['hard disk']
amazon.head()
# Out:
# <ipython-input-28-f18652a37764>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
# <ipython-input-28-f18652a37764>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
#   Price(₹)             Ratings     Reviews  \
# 0    67600  3.9 out of 5 stars  27 ratings
# 1    49990                None        None
# 2    20990  3.4 out of 5 stars   5 ratings
# 3     None  3.6 out of 5 stars  86 ratings
# 4    41500  3.4 out of 5 stars   6 ratings
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell              NaN
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI       Windows 11
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo       Windows 10
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo       Windows 10
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell              NaN
#
#                                                Model RAM(GB) Hard Disk
# 0  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8     512GB
# 1  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8       NaN
# 2  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4     256GB
# 3  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8        500
# 4  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8       1TB

# %%
amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
del amazon['Reviews'] 
del amazon['ratings'] 
amazon.head()
# Out:
# <ipython-input-29-bad9e0bf87fa>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
# <ipython-input-29-bad9e0bf87fa>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
#   Price(₹)             Ratings  \
# 0    67600  3.9 out of 5 stars
# 1    49990                None
# 2    20990  3.4 out of 5 stars
# 3     None  3.6 out of 5 stars
# 4    41500  3.4 out of 5 stars
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell              NaN
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI       Windows 11
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo       Windows 10
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo       Windows 10
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell              NaN
#
#                                                Model RAM(GB) Hard Disk  \
# 0  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8     512GB
# 1  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8       NaN
# 2  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4     256GB
# 3  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8        500
# 4  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8       1TB
#
#   Total Reviews
# 0            27
# 1          None
# 2             5
# 3            86
# 4             6

# %%
amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
del amazon['Ratings']
del amazon['Out of']  
amazon.head(10)
# Out:
# <ipython-input-30-63d71ee33523>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
# <ipython-input-30-63d71ee33523>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
#   Price(₹)                                      Product Links Company  \
# 0    67600  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1    49990  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2    20990  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3     None  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4    41500  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# 5     None  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...  Lenovo
# 6    26780  https://www.amazon.in/ASUS-VivoBook-Integrated...    ASUS
# 7    38500  https://www.amazon.in/Dell-Inspiron-Graphics-A...    Dell
# 8     None  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...      HP
# 9    22999  https://www.amazon.in/Lenovo-Celeron-Windows-M...  Lenovo
#
#   Operating_System                                              Model RAM(GB)  \
# 0              NaN  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8
# 1       Windows 11  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8
# 2       Windows 10  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4
# 3       Windows 10  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8
# 4              NaN  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8
# 5       Windows 11  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...       8
# 6       Windows 11  VivoBook 15, Intel Celeron N4020, 15.6" (39.62...       4
# 7              NaN  Inspiron 3525 Laptop, AMD Athlon Silver 3050U,...       8
# 8              NaN  HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6i...       8
# 9       Windows 11  V15 Intel Celeron N4020 15.6 inches HD Laptop ...       4
#
#   Hard Disk Total Reviews Rating
# 0     512GB            27    3.9
# 1       NaN          None   None
# 2     256GB             5    3.4
# 3       500            86    3.6
# 4       1TB             6    3.4
# 5     512GB          None   None
# 6       1TB            37    3.0
# 7     256GB           333    4.0
# 8     256GB             3    2.7
# 9     256GB             3    3.5

# %%
amazon.head(15)
# Out:
#    Price(₹)                                      Product Links Company  \
# 0     67600  https://www.amazon.in/Dell-Inspiron-i5-11320H-...    Dell
# 1     49990  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...     MSI
# 2     20990  https://www.amazon.in/Lenovo-Antiglare-Integra...  Lenovo
# 3      None  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...  Lenovo
# 4     41500  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...    Dell
# 5      None  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...  Lenovo
# 6     26780  https://www.amazon.in/ASUS-VivoBook-Integrated...    ASUS
# 7     38500  https://www.amazon.in/Dell-Inspiron-Graphics-A...    Dell
# 8      None  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...      HP
# 9     22999  https://www.amazon.in/Lenovo-Celeron-Windows-M...  Lenovo
# 10   129990  https://www.amazon.in/ASUS-Zenbook-Screen-Lapt...    ASUS
# 11    84990  https://www.amazon.in/HP-7-5800H-Graphics-Resp...      HP
# 12    99990  https://www.amazon.in/MSI-i7-12650H-Windows-Ge...     MSI
# 13     None  https://www.amazon.in/Renewed-Lenovo-ThinkPad-...  Lenovo
# 14     None  https://www.amazon.in/Refurbished-HP-Chromeboo...      HP
#
#    Operating_System                                              Model  \
# 0               NaN  Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...
# 1        Windows 11  Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...
# 2        Windows 10  E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...
# 3        Windows 10  Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...
# 4               NaN  New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...
# 5        Windows 11  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...
# 6        Windows 11  VivoBook 15, Intel Celeron N4020, 15.6" (39.62...
# 7               NaN  Inspiron 3525 Laptop, AMD Athlon Silver 3050U,...
# 8               NaN  HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6i...
# 9        Windows 11  V15 Intel Celeron N4020 15.6 inches HD Laptop ...
# 10              NaN  Zenbook Pro 14 Duo OLED (2022) Dual Screen Lap...
# 11              NaN  Victus AMD Ryzen 7-5800H 15.6 inch(39.6 cm) FH...
# 12       Windows 11  Thin GF63, Intel 12th Gen. i7-12650H, 40CM FHD...
# 13       Windows 11  Lenovo ThinkPad 6th Gen Intel Core i5 Thin & L...
# 14              NaN  HP Chromebook 11A G6 EE 11.6 inches HD Chromeb...
#
#    RAM(GB) Hard Disk Total Reviews Rating
# 0        8     512GB            27    3.9
# 1        8       NaN          None   None
# 2        4     256GB             5    3.4
# 3       8        500            86    3.6
# 4        8       1TB             6    3.4
# 5        8     512GB          None   None
# 6        4       1TB            37    3.0
# 7        8     256GB           333    4.0
# 8        8     256GB             3    2.7
# 9        4     256GB             3    3.5
# 10      16       1TB             3    4.5
# 11      16     512GB             1    5.0
# 12       8       NaN          None   None
# 13      8        256             1    4.0
# 14       4       NaN            40    3.1

# %%
amazon = amazon[['Company','Operating_System','Model','RAM(GB)', 'Hard Disk' ,'Price(₹)', 'Rating','Total Reviews','Product Links']]  #we have to del specifications if not needed
amazon
# Out:
#     Company Operating_System  \
# 0      Dell              NaN
# 1       MSI       Windows 11
# 2    Lenovo       Windows 10
# 3    Lenovo       Windows 10
# 4      Dell              NaN
# ..      ...              ...
# 378      HP              NaN
# 379    Dell              NaN
# 380    ASUS       Windows 11
# 381    Dell              NaN
# 382    Dell       Windows 11
#
#                                                  Model RAM(GB) Hard Disk  \
# 0    Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8     512GB
# 1    Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8       NaN
# 2    E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4     256GB
# 3    Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8        500
# 4    New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8       1TB
# ..                                                 ...     ...       ...
# 378  Chromebook 11a, MediaTek MT8183 Processor 11.6...      4        NaN
# 379  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...       8     512GB
# 380  Vivobook S15 OLED 2022, 15.6" 39.62 cm FHD OLE...      16     512GB
# 381  Vostro 3420 Laptop,12th Gen Intel Core i3-1215...       8     512GB
# 382  Inspiron 3511 Laptop, Intel i3-1115G4, 8GB DDR...       8     512GB
#
#     Price(₹) Rating Total Reviews  \
# 0      67600    3.9            27
# 1      49990   None          None
# 2      20990    3.4             5
# 3       None    3.6            86
# 4      41500    3.4             6
# ..       ...    ...           ...
# 378    19990    3.8           276
# 379    41990    4.1           140
# 380    72990    4.0           168
# 381    41990    4.1           140
# 382    40990    3.6            50
#
#                                          Product Links
# 0    https://www.amazon.in/Dell-Inspiron-i5-11320H-...
# 1    https://www.amazon.in/MSI-Modern-14-i3-1315U-C...
# 2    https://www.amazon.in/Lenovo-Antiglare-Integra...
# 3    https://www.amazon.in/Renewed-Lenovo-T440p-Thi...
# 4    https://www.amazon.in/Dell-Inspiron-Ryzen3-325...
# ..                                                 ...
# 378  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 379  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 380  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 381  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 382  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# [383 rows x 9 columns]

# %%
amazon.to_csv("amazon_df.csv",index = True,encoding = 'utf-8')

# %%
combined_df = pd.concat([amazon,laptops_df], ignore_index=True)

# %%
combined_df
# Out:
#      Company Operating_System  \
# 0       Dell              NaN
# 1        MSI       Windows 11
# 2     Lenovo       Windows 10
# 3     Lenovo       Windows 10
# 4       Dell              NaN
# ...      ...              ...
# 1290  Lenovo       Windows 11
# 1291    acer       Windows 10
# 1292  Lenovo       Windows 10
# 1293     MSI       Windows 11
# 1294  Lenovo       Windows 11
#
#                                                   Model RAM(GB) Hard Disk  \
# 0     Inspiron 5518 Laptop, Intel Core i5-11320H, 8G...       8     512GB
# 1     Modern 14, Intel 13th Gen. i3-1315U, 36CM FHD ...       8       NaN
# 2     E41-55 AMD 14-inch HD 220 Nits Antiglare Thin ...       4     256GB
# 3     Lenovo T440p ThinkPad 4th Gen Intel Core i5 - ...      8        500
# 4     New Inspiron 3515 Windows Laptop, AMD Ryzen3-3...       8       1TB
# ...                                                 ...     ...       ...
# 1290                 IdeaPad 3 Ryzen 5 Hexa Core 5500U       8     512 GB
# 1291                           Swift 7 Core i5 7th Gen       8     256 GB
# 1292                      Ideapad 720S Core i5 8th Gen       8     512 GB
# 1293                                  Core i3 12th Gen       8     512 GB
# 1294                  IdeaPad 3 Intel Core i3 11th Gen       8     512 GB
#
#      Price(₹) Rating Total Reviews  \
# 0       67600    3.9            27
# 1       49990   None          None
# 2       20990    3.4             5
# 3        None    3.6            86
# 4       41500    3.4             6
# ...       ...    ...           ...
# 1290    44027    4.3         1,836
# 1291    80990    4.4            39
# 1292    74990    3.3             3
# 1293    42990    4.5            11
# 1294    38990    4.3         5,175
#
#                                           Product Links
# 0     https://www.amazon.in/Dell-Inspiron-i5-11320H-...
# 1     https://www.amazon.in/MSI-Modern-14-i3-1315U-C...
# 2     https://www.amazon.in/Lenovo-Antiglare-Integra...
# 3     https://www.amazon.in/Renewed-Lenovo-T440p-Thi...
# 4     https://www.amazon.in/Dell-Inspiron-Ryzen3-325...
# ...                                                 ...
# 1290  https://www.flipkart.com/lenovo-ideapad-3-ryze...
# 1291  https://www.flipkart.com/acer-swift-7-core-i5-...
# 1292  https://www.flipkart.com/lenovo-ideapad-720s-c...
# 1293  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 1294  https://www.flipkart.com/lenovo-ideapad-3-inte...
#
# [1295 rows x 9 columns]

# %%
combined_df.to_csv("data_engg.csv",index = True,encoding = 'utf-8')
