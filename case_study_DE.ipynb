# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import numpy as np

# %% [markdown]
# # ****FOR FLIPKART WEBSITE****

# %% [markdown]
# **Data Extraction Process**

# %%
name =[]
prices = []
ratings = []
reviews = []
links = []
start_link = "https://www.flipkart.com"
df = pd.DataFrame()

# %%
page = 1
titles = []
while page != 130 :
      url = f"https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page={page}"
      response = requests.get(url)
      html = response.content   #retrieves the raw HTML content of the response, including any HTML tags, attributes, and text within the response.
      soup = BeautifulSoup(response.text,"html.parser")  # Initializes a BeautifulSoup object named soup using the HTML content as a string and specifies the parser to be used as "html.parser". 
                                                          #This allows you to parse and navigate the HTML structure of the webpage easily using BeautifulSoup methods and functions.
      data = soup.find_all("div",{"class":"_2kHMtA"})
      for h3 in soup.find_all("div",{"class":"_2kHMtA"}):

        titles.append(h3)
      page = page + 1

# %%
len(titles)  #number of laptops that were extracted
# Out:
# 984

# %%
box = titles[0]  #to check for the format in the flipkart website
box
# Out:
# <div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/lenovo-ideapad-gaming-3-ryzen-5-hexa-core-5600h-8-gb-1-tb-hdd-256-gb-ssd-windows-11-home-4-graphics-nvidia-geforce-gtx-1650-120-hz-gaming3-15ach6d1-laptop/p/itmabd3d828c1ad1?pid=COMGHMH6JRYP56GE&amp;lid=LSTCOMGHMH6JRYP56GE4TQDME&amp;marketplace=FLIPKART&amp;q=laptops&amp;store=6bo%2Fb5g&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_SutbCHmjBKxsI7OYz9v5TVaCytUcRzuCPFjGnYhgZuuRAau%2FyjB6S5wbSkeFN4mTNNTMRIJGxjMaJXLLVLJutA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=6i3nj74asw0000001684940907630&amp;qH=c06ea84a1e3dc3c6" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home/4 GB Graph..." class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/v/k/d/14iau7-gaming-laptop-lenovo-original-imaghnq4zafgebtu.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home/4 GB Graph...</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTCOMGHMH6JRYP56GE4TQDME_COMGHMH6JRYP56GE_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>25 Ratings </span><span class="_13vcmD">&amp;</span><span> 4 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">AMD Ryzen 5 Hexa Core Processor</li><li class="rgWa7D">8 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 11 Operating System</li><li class="rgWa7D">1 TB HDD|256 GB SSD</li><li class="rgWa7D">39.62 cm (15.6 Inch) Display</li><li class="rgWa7D">1 Year Onsite Warranty + 1 Year Premium Care + 1 Year Accidental Damage Protection</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹52,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->89,490</div><div class="_3Ay6Sb"><span>40% off</span></div></div><div class="_3tcB5a p8ucoS"><div><div class="_2Tpdn3" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">Upto </div><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:700">₹19,900</div><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400"> Off on Exchange</div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:12px;font-weight:400">No Cost EMI from ₹8,661/month</div></div></div></div></div></a></div>

# %%
data_list = [] 
for box in titles:   #iterating through all the laptops

  temp_dict = {}
  temp_dict["Title"] = box.find('div',{'class':'_4rR01T'}).text.strip()   #getting specifications of the product

  temp_dict["Price(₹)"] = box.find('div',{'class':'_30jeq3 _1_WHN1'}).text.replace("₹","").strip() if box.find('div',{'class':'_30jeq3 _1_WHN1'}) else None   #price of the product
  temp_dict["Rating"] = box.find('div',{'class':"_3LWZlK"}).text.strip() if box.find("div", {"class": "_3LWZlK"}) else None     #rating of the product
  temp_dict["Reviews"] = reviews = box.find('span', attrs={'class' : '_2_R_DZ'}).text if box.find('span', attrs={'class' : '_2_R_DZ'}) else None   #reviews of the product
  rest_link = box.find('a')['href']
  #name_items =box.find('div',{'class': '_1fQZEK'})
  links = (start_link + rest_link)
  temp_dict["Product Links"] = links
  data_list.append(temp_dict)

# %%
laptops_df = pd.DataFrame(data_list)
laptops_df
# Out:
#                                                  Title Price(₹) Rating  \
# 0    Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600...   52,990      4
# 1    Lenovo IdeaPad Ryzen 7 Octa Core 5800H - (16 G...   69,990    4.4
# 2    RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...   37,990    4.1
# 3    ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   34,990    4.2
# 4    ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...   54,990    4.5
# ..                                                 ...      ...    ...
# 979  MSI Core i3 12th Gen - (8 GB/512 GB SSD/Window...   42,990    4.5
# 980  DELL Core i3 11th Gen - (8 GB/1 TB HDD/Windows...   42,500    4.3
# 981  ASUS Core i3 11th Gen - (8 GB/512 GB SSD/Windo...   36,750   None
# 982  ASUS Pentium Quad Core - (8 GB/256 GB SSD/Wind...   31,900   None
# 983  Vaio SE Series Core i5 8th Gen - (8 GB/512 GB ...   58,990    3.9
#
#                          Reviews  \
# 0         25 Ratings & 4 Reviews
# 1         72 Ratings & 8 Reviews
# 2    5,507 Ratings & 622 Reviews
# 3    1,474 Ratings & 136 Reviews
# 4    5,294 Ratings & 573 Reviews
# ..                           ...
# 979       11 Ratings & 3 Reviews
# 980        7 Ratings & 0 Reviews
# 981                         None
# 982                         None
# 983      83 Ratings & 15 Reviews
#
#                                          Product Links
# 0    https://www.flipkart.com/lenovo-ideapad-gaming...
# 1    https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2    https://www.flipkart.com/redmibook-pro-core-i5...
# 3    https://www.flipkart.com/asus-vivobook-15-core...
# 4    https://www.flipkart.com/asus-tuf-gaming-f15-c...
# ..                                                 ...
# 979  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 980  https://www.flipkart.com/dell-core-i3-11th-gen...
# 981  https://www.flipkart.com/asus-core-i3-11th-gen...
# 982  https://www.flipkart.com/asus-pentium-quad-cor...
# 983  https://www.flipkart.com/vaio-se-series-core-i...
#
# [984 rows x 5 columns]

# %% [markdown]
# **Data Transformation:**

# %%
laptops_df['Price(₹)'] = laptops_df['Price(₹)'].str.replace(',', '')

# %%
laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
del laptops_df['Title']
laptops_df.head()
# Out:
# <ipython-input-19-ecca7ce829d3>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
# <ipython-input-19-ecca7ce829d3>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['model'],laptops_df['Specifications'] = laptops_df["Title"].str.split('-',1).str
#   Price(₹) Rating                      Reviews  \
# 0    52990      4       25 Ratings & 4 Reviews
# 1    69990    4.4       72 Ratings & 8 Reviews
# 2    37990    4.1  5,507 Ratings & 622 Reviews
# 3    34990    4.2  1,474 Ratings & 136 Reviews
# 4    54990    4.5  5,294 Ratings & 573 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/lenovo-ideapad-gaming...
# 1  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2  https://www.flipkart.com/redmibook-pro-core-i5...
# 3  https://www.flipkart.com/asus-vivobook-15-core...
# 4  https://www.flipkart.com/asus-tuf-gaming-f15-c...
#
#                                               model  \
# 0  Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H
# 1           Lenovo IdeaPad Ryzen 7 Octa Core 5800H
# 2                   RedmiBook Pro Core i5 11th Gen
# 3                ASUS Vivobook 15 Core i3 11th Gen
# 4             ASUS TUF Gaming F15 Core i5 10th Gen
#
#                                       Specifications
# 0   (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home/4 G...
# 1   (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphi...
# 2   (8 GB/512 GB SSD/Windows 11 Home) Thin and Li...
# 3   (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ32...
# 4   (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphic...

# %%
laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
del laptops_df['Specifications']
laptops_df.head()
# Out:
# <ipython-input-20-ee3b3de57827>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
# <ipython-input-20-ee3b3de57827>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk Drive'] = laptops_df["Specifications"].str.split('(',1).str
#   Price(₹) Rating                      Reviews  \
# 0    52990      4       25 Ratings & 4 Reviews
# 1    69990    4.4       72 Ratings & 8 Reviews
# 2    37990    4.1  5,507 Ratings & 622 Reviews
# 3    34990    4.2  1,474 Ratings & 136 Reviews
# 4    54990    4.5  5,294 Ratings & 573 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/lenovo-ideapad-gaming...
# 1  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2  https://www.flipkart.com/redmibook-pro-core-i5...
# 3  https://www.flipkart.com/asus-vivobook-15-core...
# 4  https://www.flipkart.com/asus-tuf-gaming-f15-c...
#
#                                               model RAM(GB)  \
# 0  Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H
# 1           Lenovo IdeaPad Ryzen 7 Octa Core 5800H
# 2                   RedmiBook Pro Core i5 11th Gen
# 3                ASUS Vivobook 15 Core i3 11th Gen
# 4             ASUS TUF Gaming F15 Core i5 10th Gen
#
#                                      Hard Disk Drive
# 0  8 GB/1 TB HDD/256 GB SSD/Windows 11 Home/4 GB ...
# 1  16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics...
# 2  8 GB/512 GB SSD/Windows 11 Home) Thin and Ligh...
# 3  8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322W...
# 4  8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/...

# %%
laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
del laptops_df['Hard Disk Drive']
laptops_df.head()
# Out:
# <ipython-input-21-937877900a55>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
# <ipython-input-21-937877900a55>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['RAM(GB)'],laptops_df['Hard Disk'] = laptops_df["Hard Disk Drive"].str.split('/',1).str
#   Price(₹) Rating                      Reviews  \
# 0    52990      4       25 Ratings & 4 Reviews
# 1    69990    4.4       72 Ratings & 8 Reviews
# 2    37990    4.1  5,507 Ratings & 622 Reviews
# 3    34990    4.2  1,474 Ratings & 136 Reviews
# 4    54990    4.5  5,294 Ratings & 573 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/lenovo-ideapad-gaming...
# 1  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2  https://www.flipkart.com/redmibook-pro-core-i5...
# 3  https://www.flipkart.com/asus-vivobook-15-core...
# 4  https://www.flipkart.com/asus-tuf-gaming-f15-c...
#
#                                               model RAM(GB)  \
# 0  Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H     8 GB
# 1           Lenovo IdeaPad Ryzen 7 Octa Core 5800H    16 GB
# 2                   RedmiBook Pro Core i5 11th Gen     8 GB
# 3                ASUS Vivobook 15 Core i3 11th Gen     8 GB
# 4             ASUS TUF Gaming F15 Core i5 10th Gen     8 GB
#
#                                            Hard Disk
# 0  1 TB HDD/256 GB SSD/Windows 11 Home/4 GB Graph...
# 1  512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDI...
# 2  512 GB SSD/Windows 11 Home) Thin and Light Laptop
# 3  512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thi...
# 4  512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDI...

# %%
laptops_df['RAM(GB)'] = laptops_df['RAM(GB)'].str.replace('GB', '')

# %%
laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
del laptops_df['Hard Disk']
laptops_df.head()
# Out:
# <ipython-input-23-d5977b3ecc1c>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
# <ipython-input-23-d5977b3ecc1c>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['HDD'],laptops_df['specifications'] = laptops_df["Hard Disk"].str.split('/',1).str
#   Price(₹) Rating                      Reviews  \
# 0    52990      4       25 Ratings & 4 Reviews
# 1    69990    4.4       72 Ratings & 8 Reviews
# 2    37990    4.1  5,507 Ratings & 622 Reviews
# 3    34990    4.2  1,474 Ratings & 136 Reviews
# 4    54990    4.5  5,294 Ratings & 573 Reviews
#
#                                        Product Links  \
# 0  https://www.flipkart.com/lenovo-ideapad-gaming...
# 1  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2  https://www.flipkart.com/redmibook-pro-core-i5...
# 3  https://www.flipkart.com/asus-vivobook-15-core...
# 4  https://www.flipkart.com/asus-tuf-gaming-f15-c...
#
#                                               model RAM(GB)         HDD  \
# 0  Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H       8     1 TB HDD
# 1           Lenovo IdeaPad Ryzen 7 Octa Core 5800H      16   512 GB SSD
# 2                   RedmiBook Pro Core i5 11th Gen       8   512 GB SSD
# 3                ASUS Vivobook 15 Core i3 11th Gen       8   512 GB SSD
# 4             ASUS TUF Gaming F15 Core i5 10th Gen       8   512 GB SSD
#
#                                       specifications
# 0           256 GB SSD/Windows 11 Home/4 GB Graph...
# 1     Windows 11 Home/4 GB Graphics/NVIDIA GeForc...
# 2             Windows 11 Home) Thin and Light Laptop
# 3  Windows 11 Home) X515EA-EJ322WS Thin and Light...
# 4  Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...

# %%
laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
del laptops_df['model'] 
laptops_df.head()
# Out:
# <ipython-input-24-cef07114d64a>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
# <ipython-input-24-cef07114d64a>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['Company'],laptops_df['Model'] = laptops_df["model"].str.split(' ',1).str
#   Price(₹) Rating                      Reviews  \
# 0    52990      4       25 Ratings & 4 Reviews
# 1    69990    4.4       72 Ratings & 8 Reviews
# 2    37990    4.1  5,507 Ratings & 622 Reviews
# 3    34990    4.2  1,474 Ratings & 136 Reviews
# 4    54990    4.5  5,294 Ratings & 573 Reviews
#
#                                        Product Links RAM(GB)         HDD  \
# 0  https://www.flipkart.com/lenovo-ideapad-gaming...      8     1 TB HDD
# 1  https://www.flipkart.com/lenovo-ideapad-ryzen-...     16   512 GB SSD
# 2  https://www.flipkart.com/redmibook-pro-core-i5...      8   512 GB SSD
# 3  https://www.flipkart.com/asus-vivobook-15-core...      8   512 GB SSD
# 4  https://www.flipkart.com/asus-tuf-gaming-f15-c...      8   512 GB SSD
#
#                                       specifications    Company  \
# 0           256 GB SSD/Windows 11 Home/4 GB Graph...     Lenovo
# 1     Windows 11 Home/4 GB Graphics/NVIDIA GeForc...     Lenovo
# 2             Windows 11 Home) Thin and Light Laptop  RedmiBook
# 3  Windows 11 Home) X515EA-EJ322WS Thin and Light...       ASUS
# 4  Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...       ASUS
#
#                                        Model
# 0  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H
# 1           IdeaPad Ryzen 7 Octa Core 5800H
# 2                      Pro Core i5 11th Gen
# 3              Vivobook 15 Core i3 11th Gen
# 4           TUF Gaming F15 Core i5 10th Gen

# %%
laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
del laptops_df['Reviews']  
del laptops_df['Ratings']
laptops_df.head()
# Out:
# <ipython-input-25-03ef260febaf>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
# <ipython-input-25-03ef260febaf>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   laptops_df['Total Reviews'],laptops_df['Ratings'] = laptops_df["Reviews"].str.split(' ',1).str
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    52990      4  https://www.flipkart.com/lenovo-ideapad-gaming...      8
# 1    69990    4.4  https://www.flipkart.com/lenovo-ideapad-ryzen-...     16
# 2    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
# 3    34990    4.2  https://www.flipkart.com/asus-vivobook-15-core...      8
# 4    54990    4.5  https://www.flipkart.com/asus-tuf-gaming-f15-c...      8
#
#           HDD                                     specifications    Company  \
# 0    1 TB HDD           256 GB SSD/Windows 11 Home/4 GB Graph...     Lenovo
# 1  512 GB SSD     Windows 11 Home/4 GB Graphics/NVIDIA GeForc...     Lenovo
# 2  512 GB SSD             Windows 11 Home) Thin and Light Laptop  RedmiBook
# 3  512 GB SSD  Windows 11 Home) X515EA-EJ322WS Thin and Light...       ASUS
# 4  512 GB SSD  Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...       ASUS
#
#                                        Model Total Reviews
# 0  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H             25
# 1           IdeaPad Ryzen 7 Octa Core 5800H             72
# 2                      Pro Core i5 11th Gen          5,507
# 3              Vivobook 15 Core i3 11th Gen          1,474
# 4           TUF Gaming F15 Core i5 10th Gen          5,294

# %%
regex = r"(\d+\s?(?:GB|TB))\s?(\b(?:SSD|HDD)\b)"
laptops_df[['Hard Disk', 'Storage_Type']] = laptops_df['HDD'].str.extract(regex)
del laptops_df['HDD']  
del laptops_df['Storage_Type']
laptops_df.head()
# Out:
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    52990      4  https://www.flipkart.com/lenovo-ideapad-gaming...      8
# 1    69990    4.4  https://www.flipkart.com/lenovo-ideapad-ryzen-...     16
# 2    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
# 3    34990    4.2  https://www.flipkart.com/asus-vivobook-15-core...      8
# 4    54990    4.5  https://www.flipkart.com/asus-tuf-gaming-f15-c...      8
#
#                                       specifications    Company  \
# 0           256 GB SSD/Windows 11 Home/4 GB Graph...     Lenovo
# 1     Windows 11 Home/4 GB Graphics/NVIDIA GeForc...     Lenovo
# 2             Windows 11 Home) Thin and Light Laptop  RedmiBook
# 3  Windows 11 Home) X515EA-EJ322WS Thin and Light...       ASUS
# 4  Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...       ASUS
#
#                                        Model Total Reviews Hard Disk
# 0  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H             25      1 TB
# 1           IdeaPad Ryzen 7 Octa Core 5800H             72    512 GB
# 2                      Pro Core i5 11th Gen          5,507    512 GB
# 3              Vivobook 15 Core i3 11th Gen          1,474    512 GB
# 4           TUF Gaming F15 Core i5 10th Gen          5,294    512 GB

# %%
regex = r"((?:Windows \d+|Mac OS \w+))\b(.*)"
laptops_df[['Operating_System', 'Other_Details']] = laptops_df['specifications'].str.extract(regex)
del laptops_df['specifications']
del laptops_df['Other_Details']
laptops_df
# Out:
#     Price(₹) Rating                                      Product Links  \
# 0      52990      4  https://www.flipkart.com/lenovo-ideapad-gaming...
# 1      69990    4.4  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2      37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...
# 3      34990    4.2  https://www.flipkart.com/asus-vivobook-15-core...
# 4      54990    4.5  https://www.flipkart.com/asus-tuf-gaming-f15-c...
# ..       ...    ...                                                ...
# 979    42990    4.5  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 980    42500    4.3  https://www.flipkart.com/dell-core-i3-11th-gen...
# 981    36750   None  https://www.flipkart.com/asus-core-i3-11th-gen...
# 982    31900   None  https://www.flipkart.com/asus-pentium-quad-cor...
# 983    58990    3.9  https://www.flipkart.com/vaio-se-series-core-i...
#
#     RAM(GB)    Company                                      Model  \
# 0        8      Lenovo  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H
# 1       16      Lenovo           IdeaPad Ryzen 7 Octa Core 5800H
# 2        8   RedmiBook                      Pro Core i5 11th Gen
# 3        8        ASUS              Vivobook 15 Core i3 11th Gen
# 4        8        ASUS           TUF Gaming F15 Core i5 10th Gen
# ..      ...        ...                                        ...
# 979      8         MSI                          Core i3 12th Gen
# 980      8        DELL                          Core i3 11th Gen
# 981      8        ASUS                          Core i3 11th Gen
# 982      8        ASUS                         Pentium Quad Core
# 983      8        Vaio                 SE Series Core i5 8th Gen
#
#     Total Reviews Hard Disk Operating_System
# 0              25      1 TB       Windows 11
# 1              72    512 GB       Windows 11
# 2           5,507    512 GB       Windows 11
# 3           1,474    512 GB       Windows 11
# 4           5,294    512 GB       Windows 11
# ..            ...       ...              ...
# 979            11    512 GB       Windows 11
# 980             7      1 TB       Windows 11
# 981          None    512 GB       Windows 11
# 982          None    256 GB       Windows 11
# 983            83    512 GB       Windows 10
#
# [984 rows x 9 columns]

# %%
laptops_df.head()
# Out:
#   Price(₹) Rating                                      Product Links RAM(GB)  \
# 0    52990      4  https://www.flipkart.com/lenovo-ideapad-gaming...      8
# 1    69990    4.4  https://www.flipkart.com/lenovo-ideapad-ryzen-...     16
# 2    37990    4.1  https://www.flipkart.com/redmibook-pro-core-i5...      8
# 3    34990    4.2  https://www.flipkart.com/asus-vivobook-15-core...      8
# 4    54990    4.5  https://www.flipkart.com/asus-tuf-gaming-f15-c...      8
#
#      Company                                      Model Total Reviews  \
# 0     Lenovo  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H             25
# 1     Lenovo           IdeaPad Ryzen 7 Octa Core 5800H             72
# 2  RedmiBook                      Pro Core i5 11th Gen          5,507
# 3       ASUS              Vivobook 15 Core i3 11th Gen          1,474
# 4       ASUS           TUF Gaming F15 Core i5 10th Gen          5,294
#
#   Hard Disk Operating_System
# 0      1 TB       Windows 11
# 1    512 GB       Windows 11
# 2    512 GB       Windows 11
# 3    512 GB       Windows 11
# 4    512 GB       Windows 11

# %%
laptops_df = laptops_df[['Company','Operating_System','Model','RAM(GB)', 'Hard Disk' ,'Price(₹)', 'Rating','Total Reviews','Product Links']]  #we have to del specifications if not needed
laptops_df
# Out:
#        Company Operating_System                                      Model  \
# 0       Lenovo       Windows 11  IdeaPad Gaming 3 Ryzen 5 Hexa Core 5600H
# 1       Lenovo       Windows 11           IdeaPad Ryzen 7 Octa Core 5800H
# 2    RedmiBook       Windows 11                      Pro Core i5 11th Gen
# 3         ASUS       Windows 11              Vivobook 15 Core i3 11th Gen
# 4         ASUS       Windows 11           TUF Gaming F15 Core i5 10th Gen
# ..         ...              ...                                        ...
# 979        MSI       Windows 11                          Core i3 12th Gen
# 980       DELL       Windows 11                          Core i3 11th Gen
# 981       ASUS       Windows 11                          Core i3 11th Gen
# 982       ASUS       Windows 11                         Pentium Quad Core
# 983       Vaio       Windows 10                 SE Series Core i5 8th Gen
#
#     RAM(GB) Hard Disk Price(₹) Rating Total Reviews  \
# 0        8       1 TB    52990      4            25
# 1       16     512 GB    69990    4.4            72
# 2        8     512 GB    37990    4.1         5,507
# 3        8     512 GB    34990    4.2         1,474
# 4        8     512 GB    54990    4.5         5,294
# ..      ...       ...      ...    ...           ...
# 979      8     512 GB    42990    4.5            11
# 980      8       1 TB    42500    4.3             7
# 981      8     512 GB    36750   None          None
# 982      8     256 GB    31900   None          None
# 983      8     512 GB    58990    3.9            83
#
#                                          Product Links
# 0    https://www.flipkart.com/lenovo-ideapad-gaming...
# 1    https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 2    https://www.flipkart.com/redmibook-pro-core-i5...
# 3    https://www.flipkart.com/asus-vivobook-15-core...
# 4    https://www.flipkart.com/asus-tuf-gaming-f15-c...
# ..                                                 ...
# 979  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 980  https://www.flipkart.com/dell-core-i3-11th-gen...
# 981  https://www.flipkart.com/asus-core-i3-11th-gen...
# 982  https://www.flipkart.com/asus-pentium-quad-cor...
# 983  https://www.flipkart.com/vaio-se-series-core-i...
#
# [984 rows x 9 columns]

# %%
laptops_df.to_csv("Laptops_df.csv",index = False,encoding = 'utf-8')

# %% [markdown]
# #****FOR AMAZON WEBSITE****

# %% [markdown]
# **Data Extraction**

# %%
# Function to extract Product Title
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id":'productTitle'})    # Outer Tag Object
        title_value = title.text                                  # Inner NavigatableString Object
        title_string = title_value.strip()                        # Title as a string value
    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find("span", attrs={'class':'a-price aok-align-center reinventPricePriceToPayMargin priceToPay'}).find('span', attrs= {'class' : "a-price-whole"}).text
    except AttributeError:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip() 
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:70.0) Gecko/20100101 Firefox/70.0'})  #User-Agent header is used to mimic a web browser when making HTTP requests
page = 1
links_list = []       # Store the links
    
while page != 3:
    URL = f"https://www.amazon.in/s?k=laptops&page={page}&qid=1681297837&ref=sr_pg_{page}"
    product_links = []
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})



    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
    d = {"Title":[], "Price(₹)":[], "Rating":[], "Reviews":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)
        product_links.append("https://www.amazon.in" + link)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['Title'].append(get_title(new_soup))
        d['Price(₹)'].append(get_price(new_soup))
        d['Rating'].append(get_rating(new_soup)) 
        d['Reviews'].append(get_review_count(new_soup))
    d['Product Links'] = product_links
    page = page + 1
   
    amazon = pd.DataFrame.from_dict(d)
    
    amazon['Title'].replace('', np.nan, inplace=True)
    amazon = amazon.dropna(subset=['Title'])

# %%
amazon_site = links[1]
amazon_site
# Out:
# <a class="a-link-normal s-no-outline" href="/Lenovo-IdeaPad-39-62cm-Warranty-82H802XXIN/dp/B0BN4JZVRR/ref=sr_1_18?keywords=laptops&amp;qid=1684935934&amp;sr=8-18" target="_blank"><div class="a-section aok-relative s-image-fixed-height"><img alt='Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen 15.6" (39.62cm) FHD Laptop (16GB/512GB SSD/Win 11/Office 2021/2 Years Warrant...' class="s-image" data-image-index="18" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/51pEhVQaaDL._AC_UY654_QL65_.jpg 3x"/></div></a>

# %%
amazon.head(10)
# Out:
#                                       Specifications Price(?)  \
# 0  Dell Inspiron 5518 Laptop, Intel Core i5-11320...   67,600
# 1  MSI Modern 14, Intel 13th Gen. i3-1315U, 36CM ...   49,990
# 2  Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...   20,990
# 3  (Renewed) Lenovo T440p ThinkPad 4th Gen Intel ...     None
# 4  Dell New Inspiron 3515 Windows Laptop, AMD Ryz...   41,500
# 5  (Renewed) Lenovo IdeaPad Slim 3 Intel Core i3 ...     None
# 6  ASUS VivoBook 15, Intel Celeron N4020, 15.6" (...   26,780
# 7  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...   38,500
# 8  (Renewed) HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB...     None
# 9  Lenovo V15 Intel Celeron N4020 15.6 inches HD ...   22,999
#
#               Ratings      Reviews  \
# 0  3.9 out of 5 stars   27 ratings
# 1                None         None
# 2  3.4 out of 5 stars    5 ratings
# 3  3.6 out of 5 stars   86 ratings
# 4  3.4 out of 5 stars    6 ratings
# 5                None         None
# 6  3.0 out of 5 stars   37 ratings
# 7  4.0 out of 5 stars  333 ratings
# 8  2.7 out of 5 stars    3 ratings
# 9  3.5 out of 5 stars    3 ratings
#
#                                        Product Links
# 0  https://www.amazon.in/Dell-Inspiron-i5-11320H-...
# 1  https://www.amazon.in/MSI-Modern-14-i3-1315U-C...
# 2  https://www.amazon.in/Lenovo-Antiglare-Integra...
# 3  https://www.amazon.in/Renewed-Lenovo-T440p-Thi...
# 4  https://www.amazon.in/Dell-Inspiron-Ryzen3-325...
# 5  https://www.amazon.in/Renewed-Lenovo-IdeaPad-3...
# 6  https://www.amazon.in/ASUS-VivoBook-Integrated...
# 7  https://www.amazon.in/Dell-Inspiron-Graphics-A...
# 8  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...
# 9  https://www.amazon.in/Lenovo-Celeron-Windows-M...

# %% [markdown]
# **Data Transformation**

# %%
amazon = amazon.rename(columns={'Price(?)': 'Price(₹)'})
amazon = amazon.rename(columns={'Rating': 'Ratings'})
amazon.head(10)
# Out:
#                                       Specifications Price(₹)  \
# 0  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...   36,990
# 1  Lenovo ThinkBook 14 Intel 11th Gen Core i3 14"...   40,300
# 2  HP 15s, Intel Core i3-1115G4, 15.6 inch(39.6cm...   39,990
# 3  Acer One 14 Business Laptop AMD Ryzen 3 3250U ...   28,990
# 4  ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...   49,990
# 5  ASUS Vivobook 15, Intel Core i3-1220P 12th Gen...   40,990
# 6  HP Laptop 15s, 12th Gen Intel Core i3-1215U, 1...   44,490
# 7  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...   36,990
# 8  Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...   41,990
# 9  HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...   40,990
#
#               Ratings        Reviews  \
# 0  4.1 out of 5 stars  1,365 ratings
# 1  3.9 out of 5 stars     54 ratings
# 2  4.5 out of 5 stars     17 ratings
# 3  3.9 out of 5 stars     59 ratings
# 4  4.3 out of 5 stars    288 ratings
# 5  4.0 out of 5 stars     47 ratings
# 6  4.1 out of 5 stars  1,275 ratings
# 7  4.1 out of 5 stars  1,365 ratings
# 8  4.3 out of 5 stars    381 ratings
# 9  4.1 out of 5 stars  1,275 ratings
#
#                                        Product Links
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...
# 3  https://www.amazon.in/Acer-Business-Processor-...
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...
# 5  https://www.amazon.in/ASUS-Vivobook-i3-1220P-I...
# 6  https://www.amazon.in/HP-i3-1215U-15-6-inch-Gr...
# 7  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...
# 8  https://www.amazon.in/Honor-MagicBook-Anti-Gla...
# 9  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...

# %%
amazon['Price(₹)'] = amazon['Price(₹)'].str.replace(',', '')

# %%
amazon.head()
# Out:
#                                       Specifications Price(₹)  \
# 0  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    36990
# 1  Lenovo ThinkBook 14 Intel 11th Gen Core i3 14"...    40300
# 2  HP 15s, Intel Core i3-1115G4, 15.6 inch(39.6cm...    39990
# 3  Acer One 14 Business Laptop AMD Ryzen 3 3250U ...    28990
# 4  ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...    49990
#
#               Ratings        Reviews  \
# 0  4.1 out of 5 stars  1,365 ratings
# 1  3.9 out of 5 stars     54 ratings
# 2  4.5 out of 5 stars     17 ratings
# 3  3.9 out of 5 stars     59 ratings
# 4  4.3 out of 5 stars    288 ratings
#
#                                        Product Links
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...
# 3  https://www.amazon.in/Acer-Business-Processor-...
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...

# %%
import pandas as pd

amazon['Company'] = amazon['Specifications'].str.extract(r"(?:\(Renewed\)\s)?([A-Za-z]+)")

amazon.head(10)
# Out:
#                                       Specifications Price(₹)  \
# 0  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    36990
# 1  Lenovo ThinkBook 14 Intel 11th Gen Core i3 14"...    40300
# 2  HP 15s, Intel Core i3-1115G4, 15.6 inch(39.6cm...    39990
# 3  Acer One 14 Business Laptop AMD Ryzen 3 3250U ...    28990
# 4  ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...    49990
# 5  ASUS Vivobook 15, Intel Core i3-1220P 12th Gen...    40990
# 6  HP Laptop 15s, 12th Gen Intel Core i3-1215U, 1...    44490
# 7  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    36990
# 8  Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...    41990
# 9  HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...    40990
#
#               Ratings        Reviews  \
# 0  4.1 out of 5 stars  1,365 ratings
# 1  3.9 out of 5 stars     54 ratings
# 2  4.5 out of 5 stars     17 ratings
# 3  3.9 out of 5 stars     59 ratings
# 4  4.3 out of 5 stars    288 ratings
# 5  4.0 out of 5 stars     47 ratings
# 6  4.1 out of 5 stars  1,275 ratings
# 7  4.1 out of 5 stars  1,365 ratings
# 8  4.3 out of 5 stars    381 ratings
# 9  4.1 out of 5 stars  1,275 ratings
#
#                                        Product Links Company
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3  https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# 5  https://www.amazon.in/ASUS-Vivobook-i3-1220P-I...    ASUS
# 6  https://www.amazon.in/HP-i3-1215U-15-6-inch-Gr...      HP
# 7  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP
# 8  https://www.amazon.in/Honor-MagicBook-Anti-Gla...   Honor
# 9  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP

# %%
regex = r"(?i)\b((?:Windows\s+\d+|Mac(?:Book)?|Linux|Unix|Ubuntu|DOS)\b)"
amazon['Operating_System'] = amazon['Specifications'].str.extract(regex, flags=re.IGNORECASE)
amazon['Operating_System'] = amazon['Operating_System'].str.replace('MacBook', 'Mac', regex=True)

# %%
amazon.head(124)
# Out:
#                                         Specifications Price(₹)  \
# 0    HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    36990
# 1    Lenovo ThinkBook 14 Intel 11th Gen Core i3 14"...    40300
# 2    HP 15s, Intel Core i3-1115G4, 15.6 inch(39.6cm...    39990
# 3    Acer One 14 Business Laptop AMD Ryzen 3 3250U ...    28990
# 4    ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...    49990
# ..                                                 ...      ...
# 119  ASUS VivoBook K15 OLED 2021, 15.6-inches 39.62...    63990
# 120  HP 15 11th Gen Intel Core i3 Processor 15.6-in...    41900
# 121  Dell New 14" Latitude 3420-- i5 11th Gen || 16...    80800
# 122  Lenovo ThinkBook 13s Intel 10th Gen Core i3 13...    63400
# 123  Lenovo IdeaPad Gaming 3 AMD Ryzen 7 5800H 15.6...    80990
#
#                 Ratings        Reviews  \
# 0    4.1 out of 5 stars  1,365 ratings
# 1    3.9 out of 5 stars     54 ratings
# 2    4.5 out of 5 stars     17 ratings
# 3    3.9 out of 5 stars     59 ratings
# 4    4.3 out of 5 stars    288 ratings
# ..                  ...            ...
# 119  4.0 out of 5 stars     39 ratings
# 120  3.7 out of 5 stars     63 ratings
# 121  5.0 out of 5 stars      2 ratings
# 122  4.6 out of 5 stars      5 ratings
# 123  4.4 out of 5 stars    193 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2    https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3    https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4    https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# ..                                                 ...     ...
# 119  https://www.amazon.in/ASUS-15-6-inch-i5-1135G7...    ASUS
# 120  https://www.amazon.in/HP-Processor-15-6-inch-L...      HP
# 121  https://www.amazon.in/Dell-Latitude-Windows10-...    Dell
# 122  https://www.amazon.in/Lenovo-ThinkBook-Windows...  Lenovo
# 123  https://www.amazon.in/Lenovo-IdeaPad-39-62cm-B...  Lenovo
#
#     Operating_System
# 0                NaN
# 1                DOS
# 2                NaN
# 3         Windows 11
# 4         Windows 11
# ..               ...
# 119       Windows 11
# 120              NaN
# 121       Windows 11
# 122              NaN
# 123              NaN
#
# [124 rows x 7 columns]

# %%
amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
del amazon['company']
del amazon['Specifications'] 
amazon.head()
# Out:
# <ipython-input-57-8a969cfc8a3e>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
# <ipython-input-57-8a969cfc8a3e>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['company'],amazon['Model'] = amazon["Specifications"].str.split(' ',1).str
#   Price(₹)             Ratings        Reviews  \
# 0    36990  4.1 out of 5 stars  1,365 ratings
# 1    40300  3.9 out of 5 stars     54 ratings
# 2    39990  4.5 out of 5 stars     17 ratings
# 3    28990  3.9 out of 5 stars     59 ratings
# 4    49990  4.3 out of 5 stars    288 ratings
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP              NaN
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo              DOS
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP              NaN
# 3  https://www.amazon.in/Acer-Business-Processor-...    Acer       Windows 11
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS       Windows 11
#
#                                                Model
# 0  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 1  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...
# 2  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...
# 3  One 14 Business Laptop AMD Ryzen 3 3250U Proce...
# 4  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...

# %%
import pandas as pd
import re


pattern = r"(\d+)\s?[Gg][Bb]"

# Define a function to extract RAM information from a string
def extract_ram(description):
    match = re.search(pattern, description)
    if match:
        return match.group(0)
    else:
        return None

# Apply the function to the 'Product_Description' column and create a new column 'RAM'
amazon['Model'] = amazon['Model'].astype(str)
amazon['RAM(GB)'] = amazon['Model'].apply(extract_ram)

# Print dataframe
amazon
# Out:
#     Price(₹)             Ratings        Reviews  \
# 0      36990  4.1 out of 5 stars  1,365 ratings
# 1      40300  3.9 out of 5 stars     54 ratings
# 2      39990  4.5 out of 5 stars     17 ratings
# 3      28990  3.9 out of 5 stars     59 ratings
# 4      49990  4.3 out of 5 stars    288 ratings
# ..       ...                 ...            ...
# 331    53990  4.0 out of 5 stars       1 rating
# 332    32000  3.9 out of 5 stars     43 ratings
# 333    29990       Previous page            NaN
# 334    59999  3.9 out of 5 stars    199 ratings
# 335    31990  3.7 out of 5 stars    175 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2    https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3    https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4    https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# ..                                                 ...     ...
# 331  https://www.amazon.in/ASUS-Vivobook-Laptop-Win...    ASUS
# 332  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 333  https://www.amazon.in/Lenovo-3-3250U-7200RPM-W...  Lenovo
# 334  https://www.amazon.in/Acer-12-Cores-Windows-Gr...    Acer
# 335  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...      HP
#
#     Operating_System                                              Model  \
# 0                NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 1                DOS  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...
# 2                NaN  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...
# 3         Windows 11  One 14 Business Laptop AMD Ryzen 3 3250U Proce...
# 4         Windows 11  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...
# ..               ...                                                ...
# 331       Windows 11  Vivobook Go 15 (2023), AMD Ryzen 5 7520U, 15.6...
# 332              NaN  Chromebook X360 Intel Celeron N4020 14 inch(35...
# 333              DOS  E41-55 Laptop Ryzen 3-3250U / 8GB RAM/ 1TB 720...
# 334       Windows 11  Aspire 5 Gaming Intel Core i5 12th gen (12-Cor...
# 335              NaN  15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6inch...
#
#     RAM(GB)
# 0       8GB
# 1       8GB
# 2       8GB
# 3       8GB
# 4       4GB
# ..      ...
# 331    16GB
# 332     4GB
# 333     8GB
# 334    8 GB
# 335     8GB
#
# [336 rows x 8 columns]

# %%
amazon['RAM(GB)'] = amazon['RAM(GB)'].str.replace('GB', '')

# %%
amazon['hard disk'] = amazon['Model'].str.extract(r"(\d+\s?(?:[Gg][Bb]|[Tt][Bb])?\s?(?:HDD|SSD|SDD))")

amazon
# Out:
#     Price(₹)             Ratings        Reviews  \
# 0      36990  4.1 out of 5 stars  1,365 ratings
# 1      40300  3.9 out of 5 stars     54 ratings
# 2      39990  4.5 out of 5 stars     17 ratings
# 3      28990  3.9 out of 5 stars     59 ratings
# 4      49990  4.3 out of 5 stars    288 ratings
# ..       ...                 ...            ...
# 331    53990  4.0 out of 5 stars       1 rating
# 332    32000  3.9 out of 5 stars     43 ratings
# 333    29990       Previous page            NaN
# 334    59999  3.9 out of 5 stars    199 ratings
# 335    31990  3.7 out of 5 stars    175 ratings
#
#                                          Product Links Company  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2    https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3    https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4    https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# ..                                                 ...     ...
# 331  https://www.amazon.in/ASUS-Vivobook-Laptop-Win...    ASUS
# 332  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 333  https://www.amazon.in/Lenovo-3-3250U-7200RPM-W...  Lenovo
# 334  https://www.amazon.in/Acer-12-Cores-Windows-Gr...    Acer
# 335  https://www.amazon.in/HP-15s-Ryzen-15-6inch-Mi...      HP
#
#     Operating_System                                              Model  \
# 0                NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 1                DOS  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...
# 2                NaN  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...
# 3         Windows 11  One 14 Business Laptop AMD Ryzen 3 3250U Proce...
# 4         Windows 11  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...
# ..               ...                                                ...
# 331       Windows 11  Vivobook Go 15 (2023), AMD Ryzen 5 7520U, 15.6...
# 332              NaN  Chromebook X360 Intel Celeron N4020 14 inch(35...
# 333              DOS  E41-55 Laptop Ryzen 3-3250U / 8GB RAM/ 1TB 720...
# 334       Windows 11  Aspire 5 Gaming Intel Core i5 12th gen (12-Cor...
# 335              NaN  15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6inch...
#
#     RAM(GB)   hard disk
# 0         8   256GB SSD
# 1         8   512GB SSD
# 2         8   512GB SSD
# 3         8   256GB SSD
# 4         4   512GB SSD
# ..      ...         ...
# 331      16   512GB SSD
# 332       4         NaN
# 333       8         NaN
# 334      8   512 GB SSD
# 335       8   256GB SSD
#
# [336 rows x 9 columns]

# %%
amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
del amazon['ssd'] 
del amazon['hard disk']
amazon.head()
# Out:
# <ipython-input-61-f18652a37764>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
# <ipython-input-61-f18652a37764>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Hard Disk'],amazon['ssd'] = amazon["hard disk"].str.split(' ',1).str
#   Price(₹)             Ratings        Reviews  \
# 0    36990  4.1 out of 5 stars  1,365 ratings
# 1    40300  3.9 out of 5 stars     54 ratings
# 2    39990  4.5 out of 5 stars     17 ratings
# 3    28990  3.9 out of 5 stars     59 ratings
# 4    49990  4.3 out of 5 stars    288 ratings
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP              NaN
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo              DOS
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP              NaN
# 3  https://www.amazon.in/Acer-Business-Processor-...    Acer       Windows 11
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS       Windows 11
#
#                                                Model RAM(GB) Hard Disk
# 0  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...       8     256GB
# 1  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...       8     512GB
# 2  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...       8     512GB
# 3  One 14 Business Laptop AMD Ryzen 3 3250U Proce...       8     256GB
# 4  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...       4     512GB

# %%
amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
del amazon['Reviews'] 
del amazon['ratings'] 
amazon.head()
# Out:
# <ipython-input-62-bad9e0bf87fa>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
# <ipython-input-62-bad9e0bf87fa>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Total Reviews'],amazon['ratings'] = amazon["Reviews"].str.split(' ',1).str
#   Price(₹)             Ratings  \
# 0    36990  4.1 out of 5 stars
# 1    40300  3.9 out of 5 stars
# 2    39990  4.5 out of 5 stars
# 3    28990  3.9 out of 5 stars
# 4    49990  4.3 out of 5 stars
#
#                                        Product Links Company Operating_System  \
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP              NaN
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo              DOS
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP              NaN
# 3  https://www.amazon.in/Acer-Business-Processor-...    Acer       Windows 11
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS       Windows 11
#
#                                                Model RAM(GB) Hard Disk  \
# 0  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...       8     256GB
# 1  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...       8     512GB
# 2  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...       8     512GB
# 3  One 14 Business Laptop AMD Ryzen 3 3250U Proce...       8     256GB
# 4  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...       4     512GB
#
#   Total Reviews
# 0         1,365
# 1            54
# 2            17
# 3            59
# 4           288

# %%
amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
del amazon['Ratings']
del amazon['Out of']  
amazon.head(10)
# Out:
# <ipython-input-63-63d71ee33523>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
# <ipython-input-63-63d71ee33523>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   amazon['Rating'],amazon['Out of'] = amazon["Ratings"].str.split(' ',1).str
#   Price(₹)                                      Product Links Company  \
# 0    36990  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1    40300  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2    39990  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3    28990  https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4    49990  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# 5    40990  https://www.amazon.in/ASUS-Vivobook-i3-1220P-I...    ASUS
# 6    44490  https://www.amazon.in/HP-i3-1215U-15-6-inch-Gr...      HP
# 7    36990  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP
# 8    41990  https://www.amazon.in/Honor-MagicBook-Anti-Gla...   Honor
# 9    40990  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP
#
#   Operating_System                                              Model RAM(GB)  \
# 0              NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...       8
# 1              DOS  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...       8
# 2              NaN  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...       8
# 3       Windows 11  One 14 Business Laptop AMD Ryzen 3 3250U Proce...       8
# 4       Windows 11  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...       4
# 5       Windows 11  Vivobook 15, Intel Core i3-1220P 12th Gen, 15....       8
# 6              NaN  Laptop 15s, 12th Gen Intel Core i3-1215U, 15.6...       8
# 7              NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...       8
# 8       Windows 11  MagicBook 14, AMD Ryzen 5 5500U 14-inch (35.56...      16
# 9              NaN  15s,11th Gen Intel Core i3-1115G4 8GB RAM/512G...       8
#
#   Hard Disk Total Reviews Rating
# 0     256GB         1,365    4.1
# 1     512GB            54    3.9
# 2     512GB            17    4.5
# 3     256GB            59    3.9
# 4     512GB           288    4.3
# 5     512GB            47    4.0
# 6     512GB         1,275    4.1
# 7     256GB         1,365    4.1
# 8       NaN           381    4.3
# 9     512GB         1,275    4.1

# %%
amazon.head(15)
# Out:
#    Price(₹)                                      Product Links Company  \
# 0     36990  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 1     40300  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 2     39990  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...      HP
# 3     28990  https://www.amazon.in/Acer-Business-Processor-...    Acer
# 4     49990  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...    ASUS
# 5     40990  https://www.amazon.in/ASUS-Vivobook-i3-1220P-I...    ASUS
# 6     44490  https://www.amazon.in/HP-i3-1215U-15-6-inch-Gr...      HP
# 7     36990  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP
# 8     41990  https://www.amazon.in/Honor-MagicBook-Anti-Gla...   Honor
# 9     40990  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...      HP
# 10    62990  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      HP
# 11    58700  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  Lenovo
# 12    23790  https://www.amazon.in/HP-247-G8-Warranty-67U77...      HP
# 13    65650  https://www.amazon.in/HP-Pavilion-Micro-Edge-G...      HP
# 14    51930  https://www.amazon.in/HP-i5-1155G7-Anti-Glare-...      HP
#
#    Operating_System                                              Model  \
# 0               NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 1               DOS  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...
# 2               NaN  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...
# 3        Windows 11  One 14 Business Laptop AMD Ryzen 3 3250U Proce...
# 4        Windows 11  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...
# 5        Windows 11  Vivobook 15, Intel Core i3-1220P 12th Gen, 15....
# 6               NaN  Laptop 15s, 12th Gen Intel Core i3-1215U, 15.6...
# 7               NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 8        Windows 11  MagicBook 14, AMD Ryzen 5 5500U 14-inch (35.56...
# 9               NaN  15s,11th Gen Intel Core i3-1115G4 8GB RAM/512G...
# 10              NaN  Victus Gaming Laptop 11th Gen Intel Core i5-11...
# 11       Windows 11  IdeaPad Slim 3 Intel Core i5 12th Gen 15.6" (3...
# 12       Windows 11  247 G8 Laptop (AMD Athlon P-3045B HD/ 14 inche...
# 13              NaN  Pavilion 14 12th Gen Intel Core i5 16GB RAM/51...
# 14              NaN  15s, 11th Gen Intel Core i5-1155G7, 15.6 inch(...
#
#    RAM(GB) Hard Disk Total Reviews Rating
# 0        8     256GB         1,365    4.1
# 1        8     512GB            54    3.9
# 2        8     512GB            17    4.5
# 3        8     256GB            59    3.9
# 4        4     512GB           288    4.3
# 5        8     512GB            47    4.0
# 6        8     512GB         1,275    4.1
# 7        8     256GB         1,365    4.1
# 8       16       NaN           381    4.3
# 9        8     512GB         1,275    4.1
# 10      16     512GB            21    3.3
# 11      16     512GB           570    4.1
# 12       8       1TB           236    3.5
# 13      16     512GB           305    4.1
# 14       8       512            47    4.4

# %%
amazon = amazon[['Company','Operating_System','Model','RAM(GB)', 'Hard Disk' ,'Price(₹)', 'Rating','Total Reviews','Product Links']]  #we have to del specifications if not needed
amazon.head(10)
# Out:
#   Company Operating_System                                              Model  \
# 0      HP              NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 1  Lenovo              DOS  ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...
# 2      HP              NaN  15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...
# 3    Acer       Windows 11  One 14 Business Laptop AMD Ryzen 3 3250U Proce...
# 4    ASUS       Windows 11  TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...
# 5    ASUS       Windows 11  Vivobook 15, Intel Core i3-1220P 12th Gen, 15....
# 6      HP              NaN  Laptop 15s, 12th Gen Intel Core i3-1215U, 15.6...
# 7      HP              NaN  14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...
# 8   Honor       Windows 11  MagicBook 14, AMD Ryzen 5 5500U 14-inch (35.56...
# 9      HP              NaN  15s,11th Gen Intel Core i3-1115G4 8GB RAM/512G...
#
#   RAM(GB) Hard Disk Price(₹) Rating Total Reviews  \
# 0       8     256GB    36990    4.1         1,365
# 1       8     512GB    40300    3.9            54
# 2       8     512GB    39990    4.5            17
# 3       8     256GB    28990    3.9            59
# 4       4     512GB    49990    4.3           288
# 5       8     512GB    40990    4.0            47
# 6       8     512GB    44490    4.1         1,275
# 7       8     256GB    36990    4.1         1,365
# 8      16       NaN    41990    4.3           381
# 9       8     512GB    40990    4.1         1,275
#
#                                        Product Links
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...
# 3  https://www.amazon.in/Acer-Business-Processor-...
# 4  https://www.amazon.in/ASUS-15-6-inch-GeForce-W...
# 5  https://www.amazon.in/ASUS-Vivobook-i3-1220P-I...
# 6  https://www.amazon.in/HP-i3-1215U-15-6-inch-Gr...
# 7  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...
# 8  https://www.amazon.in/Honor-MagicBook-Anti-Gla...
# 9  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...

# %%
combined_df = pd.concat([amazon,laptops_df], ignore_index=True)

# %%
combined_df
# Out:
#      Company Operating_System  \
# 0         HP              NaN
# 1     Lenovo              DOS
# 2         HP              NaN
# 3       Acer       Windows 11
# 4       ASUS       Windows 11
# ...      ...              ...
# 1315     MSI       Windows 11
# 1316    DELL       Windows 11
# 1317    ASUS       Windows 11
# 1318    ASUS       Windows 11
# 1319    Vaio       Windows 10
#
#                                                   Model RAM(GB) Hard Disk  \
# 0     14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/25...       8     256GB
# 1     ThinkBook 14 Intel 11th Gen Core i3 14" (35.56...       8     512GB
# 2     15s, Intel Core i3-1115G4, 15.6 inch(39.6cm) F...       8     512GB
# 3     One 14 Business Laptop AMD Ryzen 3 3250U Proce...       8     256GB
# 4     TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144H...       4     512GB
# ...                                                 ...     ...       ...
# 1315                                  Core i3 12th Gen       8     512 GB
# 1316                                  Core i3 11th Gen       8       1 TB
# 1317                                  Core i3 11th Gen       8     512 GB
# 1318                                 Pentium Quad Core       8     256 GB
# 1319                         SE Series Core i5 8th Gen       8     512 GB
#
#      Price(₹) Rating Total Reviews  \
# 0       36990    4.1         1,365
# 1       40300    3.9            54
# 2       39990    4.5            17
# 3       28990    3.9            59
# 4       49990    4.3           288
# ...       ...    ...           ...
# 1315    42990    4.5            11
# 1316    42500    4.3             7
# 1317    36750   None          None
# 1318    31900   None          None
# 1319    58990    3.9            83
#
#                                           Product Links
# 0     https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1     https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2     https://www.amazon.in/HP-i3-1115G4-Anti-Glare-...
# 3     https://www.amazon.in/Acer-Business-Processor-...
# 4     https://www.amazon.in/ASUS-15-6-inch-GeForce-W...
# ...                                                 ...
# 1315  https://www.flipkart.com/msi-core-i3-12th-gen-...
# 1316  https://www.flipkart.com/dell-core-i3-11th-gen...
# 1317  https://www.flipkart.com/asus-core-i3-11th-gen...
# 1318  https://www.flipkart.com/asus-pentium-quad-cor...
# 1319  https://www.flipkart.com/vaio-se-series-core-i...
#
# [1320 rows x 9 columns]

# %%
combined_df.to_csv("flip_amaz_dataset.csv",index = True,encoding = 'utf-8')
